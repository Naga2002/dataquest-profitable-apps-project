# %% [markdown]
# # Profitable App Profiles for the App Store and Google Play Markets
# Our aim in this project is to find mobile app profiles that are profitable for the App Store and Google Play markets. We're working as data analysts for a company that builds Android and iOS mobile apps, and our job is to enable our team of developers to make data-driven decisions with respect to the kind of apps they build.
#
# At our company, we only build apps that are free to download and install, and our main source of revenue consists of in-app ads. This means that our revenue for any given app is mostly influenced by the number of users that use our app. Our goal for this project is to analyze data to help our developers understand what kinds of apps are likely to attract more users.

# %%
from csv import reader
import re

### The Google Play data set ###
opened_file = open('googleplaystore.csv')
read_file = reader(opened_file)
tmp_list = list(read_file)
android_header = tmp_list[0]
android = tmp_list[1:]

### The Apple App Store data set ###
opened_file = open('AppleStore.csv')
read_file = reader(opened_file)
tmp_list = list(read_file)
ios_header = tmp_list[0]
ios = tmp_list[1:]

# %% [markdown]
# ## Explore Data function
# Define explore_data() function to assis in previwing data easily

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line after each row

    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %%
explore_data(android, 0, 5, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# Number of rows: 10841
# Number of columns: 13

# %%
explore_data(ios, 0, 5, True)
# Out:
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# ['284035177', 'Pandora - Music & Radio', '130242560', 'USD', '0.0', '1126879', '3594', '4.0', '4.5', '8.4.1', '12+', 'Music', '37', '4', '1', '1']
#
#
# Number of rows: 7197
# Number of columns: 16

# %% [markdown]
# ## Find bad rows
# Find any rows that are not the same length (missing fields):

# %%
for row in android[0:]:
    if len(row) != len(android[0]):
        print(android.index(row))
        print(len(row))
# Out:
# 10472
# 12

# %% [markdown]
# Row index 10472 is missing the 'Category' (2nd) field. It does not have a very high rating (1.9) so is unlikely to be impactful to our analysis, so lets just remove it. Add the app_name qualifier so as not to remove other rows by multiple runs:

# %%
print(android[10472])
if android[10472][0] == 'Life Made WI-Fi Touchscreen Photo Frame':
    del android[10472]
print(android[10472])
# Out:
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
# ['osmino Wi-Fi: free WiFi', 'TOOLS', '4.2', '134203', '4.1M', '10,000,000+', 'Free', '0', 'Everyone', 'Tools', 'August 7, 2018', '6.06.14', '4.4 and up']

# %% [markdown]
# The ios dataset does not have any rows missing fields. All are the same length:

# %%
for row in ios[0:]:
    if len(row) != len(ios[0]):
        print(ios.index(row))
        print(len(row))

# %% [markdown]
# ## Identify if dupe apps exist
# Create function to find duplicate apps by their app_name. Accept the index of the app name field so it can be used for multiple datasets. Return the list of dupe app names:

# %%
def find_dupes(dataset, app_name_index):
    unique = []
    dupes = []
    for row in dataset:
        app_name = row[app_name_index]
        if app_name in unique:
            dupes.append(app_name)
        else:            
            unique.append(app_name)
    return dupes

# %%
ios_dupes = find_dupes(ios,1)
print(ios_dupes)
### found 2 dupes in ios dataset:
# Out:
# ['Mannequin Challenge', 'VR Roller Coaster']

# %%
android_dupes = find_dupes(android,0)
print(len(android_dupes))
print(android_dupes[0:15])
### android dataset has 1181 dupe apps
# Out:
# 1181
# ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads', 'Google My Business', 'Slack', 'FreshBooks Classic', 'Insightly CRM', 'QuickBooks Accounting: Invoicing & Expenses', 'HipChat - Chat Built for Teams', 'Xero Accounting Software']

# %% [markdown]
# ## Determine how dupes can be fixed
# Create a function to view all the rows with a single app_name

# %%
def print_app_by_value(dataset, index_of_field, field_value):
    for row in dataset:
        app_value = row[index_of_field]
        if app_value == field_value:
            print(row)

# %%
print_app_by_value(ios,1,'VR Roller Coaster')
# Out:
# ['952877179', 'VR Roller Coaster', '169523200', 'USD', '0.0', '107', '102', '3.5', '3.5', '2.0.0', '4+', 'Games', '37', '5', '1', '1']
# ['1089824278', 'VR Roller Coaster', '240964608', 'USD', '0.0', '67', '44', '3.5', '4.0', '0.81', '4+', 'Games', '38', '0', '1', '1']

# %%
print_app_by_value(android,0,'Instagram')
# Out:
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %% [markdown]
# Base on what we see above, we can use choose to keep the app row with the most reviews

# %% [markdown]
# Write a function to delete dupes, keeping the app row with the most reviews:

# %%
def create_max_reviews_dict(dataset, app_name_index, reviews_index):
    reviews_max = {}
    for row in dataset:
        app_name = row[app_name_index]
        n_reviews = float(row[reviews_index])
        if app_name in reviews_max and reviews_max[app_name] < n_reviews:
            reviews_max[app_name] = n_reviews
        if app_name not in reviews_max:
            reviews_max[app_name] = n_reviews
    return reviews_max

# %% [markdown]
# ## Confirm results for dedupe strategy
# Verify a value from each dataset. Make sure the reviews amount is indeed the largest for that app_name. Also verify the length of reviews_max is `total - dupes`.

# %%
# index mapping
# ios[1] = "track_name": App Name
# ios[5] = "ratingcounttot": User Rating counts (for all version)
ios_review_max = create_max_reviews_dict(ios,1,5)

print (ios_review_max['VR Roller Coaster'])
print ('Total with max reviews: ', len(ios_review_max))
print ('Expected Total - Dupes: ', len(ios) - len(ios_dupes))
# Out:
# 107.0
# Total with max reviews:  7195
# Expected Total - Dupes:  7195

# %%
# index mapping
# android[0] = "App": Application name
# android[3] = "Reviews": Number of user reviews for the app (as when scraped)
android_review_max = create_max_reviews_dict(android,0,3)

print (android_review_max['Instagram'])
print ('Total with max reviews: ', len(android_review_max))
print ('Expected Total - Dupes: ', len(android) - len(android_dupes))
# Out:
# 66577446.0
# Total with max reviews:  9659
# Expected Total - Dupes:  9659

# %% [markdown]
# ## Create unique datasets
# Create a function that takes in the original dataset and the review_max dataset and returns a clean dataset of unique apps with all the same fields as the original.

# %%
def create_clean_dataset(dataset_orig, dict_review_max, app_name_index, reviews_index):
    dataset_clean = []
    already_added = []
    
    for row in dataset_orig:
        app_name = row[app_name_index]
        n_reviews = float(row[reviews_index])
        
        if n_reviews == dict_review_max[app_name] and app_name not in already_added:
            dataset_clean.append(row)
            already_added.append(app_name)
    
    return dataset_clean

# %%
# index mapping
# ios[1] = "track_name": App Name
# ios[5] = "ratingcounttot": User Rating counts (for all version)
ios_clean = create_clean_dataset(ios,ios_review_max,1,5)

print(len(ios_clean))
explore_data(ios_clean, 0, 5)
# Out:
# 7195
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# ['284035177', 'Pandora - Music & Radio', '130242560', 'USD', '0.0', '1126879', '3594', '4.0', '4.5', '8.4.1', '12+', 'Music', '37', '4', '1', '1']

# %%
# index mapping
# android[0] = "App": Application name
# android[3] = "Reviews": Number of user reviews for the app (as when scraped)
android_clean = create_clean_dataset(android,android_review_max,0,3)

print(len(android_clean))
explore_data(android_clean, 0, 5)
# Out:
# 9659
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']

# %% [markdown]
# ## Find non-english apps
# Our analysis should not include apps that are clearly not in english.

# %%
print(ios[813][1])
print(ios[6731][1])
print(ord('爱'))
# Out:
# 爱奇艺PPS -《欢乐颂2》电视剧热播
# 【脱出ゲーム】絶対に最後までプレイしないで 〜謎解き＆ブロックパズル〜
# 29233

# %% [markdown]
# Create function that takes in a string and returns `False` if any character doesn't belong in the set of common English characters (Ord() > 127); otherwise return `True`

# %%
def is_english(string_input):
    for character in string_input:
        if ord(character) > 127:
            return False
    return True

# %%
#test function with some values
print(is_english('Instagram'))
print(is_english('爱奇艺PPS -《欢乐颂2》电视剧热播'))
print(is_english('Docs To Go™ Free Office Suite'))
print(is_english('Instachat 😜'))
# Out:
# True
# False
# False
# False

# %%
# index mapping
# ios[1] = "track_name": App Name
ios_non_english_apps = []

for row in ios_clean:
    if not is_english(row[1]):
        ios_non_english_apps.append(row[1])

print(len(ios_non_english_apps))      
explore_data(ios_non_english_apps,1,5)
# Out:
# 1490
# The Sims™ FreePlay
#
#
# 8 Ball Pool™
#
#
# Lose It! – Weight Loss Program and Calorie Counter
#
#
# ▻Sudoku

# %%
# index mapping
# android[0] = "App": Application name
android_non_english_apps = []

for row in android_clean:
    if not is_english(row[0]):
        android_non_english_apps.append(row[0])

print(len(android_non_english_apps))      
explore_data(android_non_english_apps,1,5)
# Out:
# 542
# CarMax – Cars for Sale: Search Used Car Inventory
#
#
# AutoScout24 Switzerland – Find your new car
#
#
# Zona Azul Digital Fácil SP CET - OFFICIAL São Paulo
#
#
# ReadEra – free ebook reader

# %% [markdown]
# The current version of the non_english function is excluding apps that we want to keep:
# - 'The Sims™ FreePlay'
# - 'Lose It! – Weight Loss Program and Calorie Counter'
# - '▻Sudoku'
# - 'CarMax – Cars for Sale: Search Used Car Inventory'
#
# Let's adjust it to have a minimum of 5 non-english characters before calling it non-english

# %%
#after redefining this funciton, check results again
def is_english(string_input):
    string_len = float(len(string_input))
    non_english_count = 0
    percent_of_total = 0.0
    
    for character in string_input:
        if ord(character) > 127:
            non_english_count += 1
            percent_of_total = non_english_count / string_len
        if percent_of_total > 0.5:
            return False
    return True

# %%
# index mapping
# ios[1] = "track_name": App Name
ios_non_english_apps = []

for row in ios_clean:
    if not is_english(row[1]):
        ios_non_english_apps.append(row[1])

print(len(ios_non_english_apps))      
explore_data(ios_non_english_apps,1,5)
# Out:
# 958
# 聚力视频HD-人民的名义,跨界歌王全网热播
#
#
# 优酷视频
#
#
# 网易新闻 - 精选好内容，算出你的兴趣
#
#
# 淘宝 - 随时随地，想淘就淘

# %%
# index mapping
# android[0] = "App": Application name
android_non_english_apps = []

for row in android_clean:
    if not is_english(row[0]):
        android_non_english_apps.append(row[0])

print(len(android_non_english_apps))      
explore_data(android_non_english_apps,1,5)
# Out:
# 24
# РИА Новости
#
#
# صور حرف H
#
#
# RMEduS - 음성인식을 활용한 R 프로그래밍 실습 시스템
#
#
# AJ렌터카 법인 카셰어링

# %% [markdown]
# The first version of the function detected many "non-english" apps, but upon investigating, some where apps we want to keep:
#
# - ios: 1490
# - android: 542
#
# With the updated function we now have better results:
#
# - ios: 958
# - android: 24
#
# And our sample shows:
# - 聚力视频HD-人民的名义,跨界歌王全网热播
# - 网易新闻 - 精选好内容，算出你的兴趣
# - صور حرف H
# - RMEduS - 음성인식을 활용한 R 프로그래밍 실습 시스템

# %%
def create_english_dataset(dataset_orig, app_name_index):
    dataset_english = []
    
    for row in dataset_orig:
        app_name = row[app_name_index]
        
        if is_english(app_name):
            dataset_english.append(row)
    
    return dataset_english

# %%
# index mapping
# ios[1] = "track_name": App Name
ios_english = create_english_dataset(ios_clean,1)

# confirm the count of ios_english
print('English length: ',len(ios_english))
print('Expected length: ',len(ios_clean) - len(ios_non_english_apps))
explore_data(ios_english, 0, 5)
# Out:
# English length:  6237
# Expected length:  6237
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# ['284035177', 'Pandora - Music & Radio', '130242560', 'USD', '0.0', '1126879', '3594', '4.0', '4.5', '8.4.1', '12+', 'Music', '37', '4', '1', '1']

# %%
# index mapping
# android[0] = "App": Application name
android_english = create_english_dataset(android_clean,0)

# confirm the count of android_english
print('English length: ',len(android_english))
print('Expected length: ',len(android_clean) - len(android_non_english_apps))
explore_data(android_english, 0, 5)
# Out:
# English length:  9635
# Expected length:  9635
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']

# %% [markdown]
# ## Restricting to Free Apps
# So far in the data cleaning process, we've done the following:
#
# - Removed inaccurate data
# - Removed duplicate app entries
# - Removed non-English apps
#
# As we mentioned in the introduction, we only build apps that are free to download and install, and our main source of revenue consists of in-app ads. Our datasets contain both free and non-free apps, so let's filter down to just free apps.

# %%
def create_free_dataset(dataset_orig, price_index):
    dataset_free = []
    
    for row in dataset_orig:
        price_string = row[price_index]
        #clean string before converting to float
        
        price = float(re.sub('[^\d\.]', '',price_string))
        
        if price == 0:
            dataset_free.append(row)
    
    return dataset_free

# %%
# index mapping
# ios[4] = "price": Price amount
ios_free = create_free_dataset(ios_english,4)

# show count of free apps and confirm a few
print('free length: ',len(ios_free))
explore_data(ios_free, 0, 5)
# Out:
# free length:  3263
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# ['284035177', 'Pandora - Music & Radio', '130242560', 'USD', '0.0', '1126879', '3594', '4.0', '4.5', '8.4.1', '12+', 'Music', '37', '4', '1', '1']

# %%
# index mapping
# android[7] = "Price": Price of the app (as when scraped)
android_free = create_free_dataset(android_english,7)

# show count of free apps and confirm a few
print('free length: ',len(android_free))
explore_data(android_free, 0, 5)
# Out:
# free length:  8882
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']

# %% [markdown]
# We have the remaining number of clean free apps:
# - ios_free:     3,263
# - android_free: 8,882

# %% [markdown]
# ## Start the Analysis
# ### Find most popular apps by genre
# As mentioned before, our company only builds free to install apps and makes revenue from ads. Therefore, we want to build an app that attracts the most users.
#
# Our strategy for developing a new app will follow these steps:
# 1. Build a minimal Android version of the app, and add it to Google Play.
# 2. If the app has a good response from users, we develop it further.
# 3. If the app is profitable after six months, we build an iOS version of the app and add it to the App Store.
#
# ### Part 1 - common genres
# Since our app needs to be successful for both Android and iOS, we start by looking at the most common genres in both datasets and look for comminalities. Let's start by developing a function the builds a frequency table for a given field index.

# %%
def freq_table(dataset, index):
    table = {}
    total = 0
    
    for row in dataset:
        total += 1
        value = row[index]
        if value in table:
            table[value] += 1
        else:
            table[value] = 1
    
    table_percentages = {}
    for key in table:
        percentage = (table[key] / total) * 100
        table_percentages[key] = percentage 
    
    return table_percentages

# %%
# index mapping
# ios_free[11] = "prime_genre": Primary Genre
ios_freq_table_genre = freq_table(ios_free, 11)

# %%
print(ios_freq_table_genre)
# Out:
# {'Social Networking': 3.2178976402083976, 'Photo & Video': 4.96475635917867, 'Games': 57.98345081213607, 'Music': 2.0226785167024213, 'Reference': 0.5516395954642966, 'Health & Fitness': 1.9920318725099602, 'Weather': 0.8581060373889058, 'Utilities': 2.5130248237817963, 'Travel': 1.2565124118908981, 'Shopping': 2.63561140055164, 'News': 1.3484523444682808, 'Navigation': 0.18387986515476554, 'Lifestyle': 1.6242721422004291, 'Entertainment': 8.029420778424763, 'Food & Drink': 0.9193993257738278, 'Sports': 2.1146184492798037, 'Book': 0.4596996628869139, 'Finance': 1.1032791909285933, 'Education': 3.6163040147103893, 'Productivity': 1.7468587189702727, 'Business': 0.5209929512718358, 'Catalogs': 0.12258657676984369, 'Medical': 0.21452650934722645}

# %% [markdown]
# This gives us the percentages, but it is diffuclt to see the most common one with them out of order. Let's build another function to order our freqency tables.

# %%
def display_table(freq_table):
    table_display = []
    for key in freq_table:
        key_val_as_tuple = (freq_table[key], key)
        table_display.append(key_val_as_tuple)
        
    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %%
display_table(ios_freq_table_genre)
# Out:
# Games : 57.98345081213607
# Entertainment : 8.029420778424763
# Photo & Video : 4.96475635917867
# Education : 3.6163040147103893
# Social Networking : 3.2178976402083976
# Shopping : 2.63561140055164
# Utilities : 2.5130248237817963
# Sports : 2.1146184492798037
# Music : 2.0226785167024213
# Health & Fitness : 1.9920318725099602
# Productivity : 1.7468587189702727
# Lifestyle : 1.6242721422004291
# News : 1.3484523444682808
# Travel : 1.2565124118908981
# Finance : 1.1032791909285933
# Food & Drink : 0.9193993257738278
# Weather : 0.8581060373889058
# Reference : 0.5516395954642966
# Business : 0.5209929512718358
# Book : 0.4596996628869139
# Medical : 0.21452650934722645
# Navigation : 0.18387986515476554
# Catalogs : 0.12258657676984369

# %% [markdown]
# It appears that over 57% of the iOS Apps (free and english) are games and another 8% are for entertainment.
#
# Let's do the same analytis for the Android category.

# %%
# index mapping
# android_free[1] = "Category:": Category the app belongs to
display_table(freq_table(android_free,1))
# Out:
# FAMILY : 18.937176311641522
# GAME : 9.716280117090745
# TOOLS : 8.444044134204008
# BUSINESS : 4.59356000900698
# LIFESTYLE : 3.9292952037829316
# PRODUCTIVITY : 3.8955190272461158
# FINANCE : 3.6928619680252197
# MEDICAL : 3.5239810853411395
# SPORTS : 3.388876379193875
# PERSONALIZATION : 3.3213240261202435
# COMMUNICATION : 3.231254222022067
# HEALTH_AND_FITNESS : 3.073632064850259
# PHOTOGRAPHY : 2.938527358702995
# NEWS_AND_MAGAZINES : 2.814681378068003
# SOCIAL : 2.6570592208961945
# TRAVEL_AND_LOCAL : 2.3305561810403064
# SHOPPING : 2.24048637694213
# BOOKS_AND_REFERENCE : 2.161675298356226
# DATING : 1.8576897095248817
# VIDEO_PLAYERS : 1.7901373564512497
# MAPS_AND_NAVIGATION : 1.4073406890340014
# FOOD_AND_DRINK : 1.238459806349921
# EDUCATION : 1.159648727764017
# ENTERTAINMENT : 0.956991668543121
# LIBRARIES_AND_DEMO : 0.9344742175185768
# AUTO_AND_VEHICLES : 0.9232154920063049
# HOUSE_AND_HOME : 0.8218869623958567
# WEATHER : 0.7993695113713127
# EVENTS : 0.7092997072731367
# PARENTING : 0.6530060797117767
# ART_AND_DESIGN : 0.6417473541995046
# COMICS : 0.6192299031749605
# BEAUTY : 0.5967124521504166

# %% [markdown]
# For Andoid, it appears less than 10% are games, however, if we go to the play store and look at the FAMILY category, we see these are mostly kids' games, so let's lump them together and say about 20% of the apps are games for Android.
#
# There was a second field in the android data called `Genres`, so let's see if that field gives us any more clarity:

# %%
# index mapping
# android_free[9] = "Genres:": An app can belong to multiple genres (apart from its main category)
display_table(freq_table(android_free,9))
# Out:
# Tools : 8.432785408691736
# Entertainment : 6.079711776626886
# Education : 5.359153343841477
# Business : 4.59356000900698
# Lifestyle : 3.91803647827066
# Productivity : 3.8955190272461158
# Finance : 3.6928619680252197
# Medical : 3.5239810853411395
# Sports : 3.4564287322675074
# Personalization : 3.3213240261202435
# Communication : 3.231254222022067
# Action : 3.096149515874803
# Health & Fitness : 3.073632064850259
# Photography : 2.938527358702995
# News & Magazines : 2.814681378068003
# Social : 2.6570592208961945
# Travel & Local : 2.319297455528034
# Shopping : 2.24048637694213
# Books & Reference : 2.161675298356226
# Simulation : 2.037829317721234
# Dating : 1.8576897095248817
# Arcade : 1.8464309840126099
# Video Players & Editors : 1.7676199054267057
# Casual : 1.7563611799144336
# Maps & Navigation : 1.4073406890340014
# Food & Drink : 1.238459806349921
# Puzzle : 1.125872551227201
# Racing : 0.990767845079937
# Role Playing : 0.9344742175185768
# Libraries & Demo : 0.9344742175185768
# Strategy : 0.9232154920063049
# Auto & Vehicles : 0.9232154920063049
# House & Home : 0.8218869623958567
# Weather : 0.7993695113713127
# Events : 0.7092997072731367
# Adventure : 0.6867822562485927
# Comics : 0.6079711776626886
# Beauty : 0.5967124521504166
# Art & Design : 0.5967124521504166
# Parenting : 0.4953839225399685
# Card : 0.45034902049088044
# Casino : 0.4278315694663364
# Trivia : 0.4165728439540644
# Educational;Education : 0.39405539292952035
# Board : 0.3827966674172484
# Educational : 0.37153794190497635
# Education;Education : 0.3490204908804323
# Word : 0.25895068678225625
# Casual;Pretend Play : 0.23643323575771222
# Music : 0.20265705922089622
# Racing;Action & Adventure : 0.16888088268408016
# Puzzle;Brain Games : 0.16888088268408016
# Entertainment;Music & Video : 0.16888088268408016
# Casual;Brain Games : 0.13510470614726414
# Casual;Action & Adventure : 0.13510470614726414
# Arcade;Action & Adventure : 0.12384598063499212
# Action;Action & Adventure : 0.10132852961044811
# Educational;Pretend Play : 0.09006980409817608
# Simulation;Action & Adventure : 0.07881107858590408
# Parenting;Education : 0.07881107858590408
# Entertainment;Brain Games : 0.07881107858590408
# Board;Brain Games : 0.07881107858590408
# Parenting;Music & Video : 0.06755235307363207
# Educational;Brain Games : 0.06755235307363207
# Casual;Creativity : 0.06755235307363207
# Art & Design;Creativity : 0.06755235307363207
# Education;Pretend Play : 0.056293627561360055
# Role Playing;Pretend Play : 0.04503490204908804
# Education;Creativity : 0.04503490204908804
# Role Playing;Action & Adventure : 0.033776176536816034
# Puzzle;Action & Adventure : 0.033776176536816034
# Entertainment;Creativity : 0.033776176536816034
# Entertainment;Action & Adventure : 0.033776176536816034
# Educational;Creativity : 0.033776176536816034
# Educational;Action & Adventure : 0.033776176536816034
# Education;Music & Video : 0.033776176536816034
# Education;Brain Games : 0.033776176536816034
# Education;Action & Adventure : 0.033776176536816034
# Adventure;Action & Adventure : 0.033776176536816034
# Video Players & Editors;Music & Video : 0.02251745102454402
# Sports;Action & Adventure : 0.02251745102454402
# Simulation;Pretend Play : 0.02251745102454402
# Puzzle;Creativity : 0.02251745102454402
# Music;Music & Video : 0.02251745102454402
# Entertainment;Pretend Play : 0.02251745102454402
# Casual;Education : 0.02251745102454402
# Board;Action & Adventure : 0.02251745102454402
# Video Players & Editors;Creativity : 0.01125872551227201
# Trivia;Education : 0.01125872551227201
# Travel & Local;Action & Adventure : 0.01125872551227201
# Tools;Education : 0.01125872551227201
# Strategy;Education : 0.01125872551227201
# Strategy;Creativity : 0.01125872551227201
# Strategy;Action & Adventure : 0.01125872551227201
# Simulation;Education : 0.01125872551227201
# Role Playing;Brain Games : 0.01125872551227201
# Racing;Pretend Play : 0.01125872551227201
# Puzzle;Education : 0.01125872551227201
# Parenting;Brain Games : 0.01125872551227201
# Music & Audio;Music & Video : 0.01125872551227201
# Lifestyle;Pretend Play : 0.01125872551227201
# Lifestyle;Education : 0.01125872551227201
# Health & Fitness;Education : 0.01125872551227201
# Health & Fitness;Action & Adventure : 0.01125872551227201
# Entertainment;Education : 0.01125872551227201
# Communication;Creativity : 0.01125872551227201
# Comics;Creativity : 0.01125872551227201
# Casual;Music & Video : 0.01125872551227201
# Card;Action & Adventure : 0.01125872551227201
# Books & Reference;Education : 0.01125872551227201
# Art & Design;Pretend Play : 0.01125872551227201
# Art & Design;Action & Adventure : 0.01125872551227201
# Arcade;Pretend Play : 0.01125872551227201
# Adventure;Education : 0.01125872551227201

# %% [markdown]
# This appears to be much more detailed and breaks down our "Games" category into a bunch of sub-genres. This is not helpful in comparing to iOS, so we'll just use the analysis from the `Category` field going forward.

# %% [markdown]
# ### Part 2 - Check user counts per genre
# Our frequency tables above simply tell us how many of the free-english apps were created in each genre. It doesn't neccessarily mean those apps draw the most users. Remember, since the app we are developing will be ad-revenue based, we want as many people using the app as possible.
#
# The Android dataset has a field called `Installs`, but the iOS dataset does not have a comparable field. Instead, let's go with user review counts to determine the popularity of an app. Regardless if the review is good or bad, we can infer the user likey used the app long enough to be able to give a review.
#
# For iOS, we'll use `rating_count_tot` to count the ratings for all versions of the app. On Android, the field will be `Reviews`.
#
# For each genre, we'll want to calculate the average number of reviews per app, this way, the shear number of apps in a genre will not skew our totals.
#
# To do this, we'll create a new function that takes in our previous frequency tables (dictionaries). We'll loop through each genre key, looking for apps that match that genre. For each app found, we'll sum the total user ratings as well as keep track of how many apps for that genre we enountered. At the end, we'll do the division to calculate the average per genre.

# %%
def avg_user_counts(dataset, genre_index, count_index, freq_table):
    genre_avg_user_counts = {}
    
    for genre in freq_table:
        total = 0
        len_genre = 0
        
        for row in dataset:
            genre_app = row[genre_index]
            
            if genre_app == genre:
                ratings_count = float(row[count_index])
                total += ratings_count
                len_genre += 1
        
        avg_user_counts = total / len_genre
        genre_avg_user_counts[genre] = avg_user_counts
    
    return genre_avg_user_counts

# %%
# index mapping
# ios_free[11] = "prime_genre": Primary Genre
# ios_free[5] = "rating_count_tot": User Rating counts (for all version)
display_table(avg_user_counts(ios_free, 11, 5, freq_table(ios_free, 11)))
# Out:
# Navigation : 86090.33333333333
# Reference : 74942.11111111111
# Social Networking : 72222.84761904762
# Music : 57326.530303030304
# Weather : 52279.892857142855
# Book : 37107.933333333334
# Finance : 31468.027777777777
# Food & Drink : 28891.033333333333
# Photo & Video : 28090.413580246914
# Travel : 27551.219512195123
# Shopping : 26293.732558139534
# Health & Fitness : 23298.015384615384
# Sports : 23008.898550724636
# Games : 22572.40539112051
# News : 20765.113636363636
# Productivity : 20659.491228070176
# Utilities : 18467.256097560974
# Lifestyle : 15872.924528301886
# Entertainment : 13602.141221374046
# Business : 7491.117647058823
# Education : 7003.983050847458
# Catalogs : 4004.0
# Medical : 525.4285714285714

# %%
# index mapping
# android_free[1] = "Category:": Category the app belongs to
# android_free[3] = "Reviews": Number of user reviews for the app (as when scraped)
display_table(avg_user_counts(android_free, 1, 3, freq_table(android_free, 1)))
# Out:
# COMMUNICATION : 995608.4634146341
# SOCIAL : 965830.9872881356
# GAME : 682733.6234067207
# VIDEO_PLAYERS : 425350.08176100627
# PHOTOGRAPHY : 404081.3754789272
# TOOLS : 305732.8973333333
# ENTERTAINMENT : 301752.24705882353
# SHOPPING : 223887.34673366835
# PERSONALIZATION : 180508.3525423729
# WEATHER : 171250.77464788733
# PRODUCTIVITY : 160170.91040462427
# MAPS_AND_NAVIGATION : 141775.68
# TRAVEL_AND_LOCAL : 129484.42512077295
# SPORTS : 116938.6146179402
# FAMILY : 112837.6694411415
# NEWS_AND_MAGAZINES : 92343.584
# BOOKS_AND_REFERENCE : 87087.75520833333
# HEALTH_AND_FITNESS : 78094.9706959707
# FOOD_AND_DRINK : 57478.79090909091
# EDUCATION : 56293.09708737864
# COMICS : 42585.61818181818
# FINANCE : 38535.8993902439
# LIFESTYLE : 33767.031518624644
# HOUSE_AND_HOME : 26435.465753424658
# ART_AND_DESIGN : 24699.42105263158
# BUSINESS : 24181.105392156864
# DATING : 21953.272727272728
# PARENTING : 16378.706896551725
# AUTO_AND_VEHICLES : 14140.280487804877
# LIBRARIES_AND_DEMO : 10925.807228915663
# BEAUTY : 7476.226415094339
# MEDICAL : 3730.1533546325877
# EVENTS : 2555.84126984127

# %% [markdown]
# Now that were a looking the popularity of the apps, we can see the top three genres for iOS are:
# 1. Navigation : 86090
# 2. Reference : 74942
# 3. Social Networking : 72222
#
# And for Android:
# 1. COMMUNICATION : 995608
# 2. SOCIAL : 965830
# 3. GAME : 682733
#
# We see `Social` in both top 3's, but I suspect those numbers are going to be dominated by some very well established social media apps like Facebook and Twitter.
#
# ### Part 3 - Check for apps skewing the averages
#
# Let's create another function to see the ratings counts of each app in a specific genre.

# %%
def app_percent_of_user_counts(dataset, genre_index, genre_filter, count_index, app_name_index):
    app_counts_dict = {}
    total_ratings = 0
    
    for row in dataset:
        app_genre = row[genre_index]
            
        if app_genre == genre_filter:
            ratings_count = float(row[count_index])
            total_ratings += ratings_count
            app_name = row[app_name_index]
            app_counts_dict[app_name] = ratings_count
    
    #convert each app's ratings count to a percentage of total
    for key, value in app_counts_dict.items():
        app_counts_dict[key] = round(value / total_ratings * 100.00,2)
    
    return app_counts_dict

# %%
# index mapping
# ios_free[11] = "prime_genre": Primary Genre
# ios_free[5] = "rating_count_tot": User Rating counts (for all version)
# ios_free[1] = "track_name": App Name
# Navigation : 86090.33333333333
# Reference : 74942.11111111111
# Social Networking : 72222.84761904762
display_table(app_percent_of_user_counts(ios_free, 11, 'Weather', 5, 1))
# Out:
# The Weather Channel: Forecast, Radar & Alerts : 33.86
# The Weather Channel App for iPad – best local forecast, radar map, and storm tracking : 14.25
# WeatherBug - Local Weather, Radar, Maps, Alerts : 12.88
# MyRadar NOAA Weather Radar Forecast : 10.26
# AccuWeather - Weather for Life : 9.85
# Yahoo Weather : 7.69
# Weather Underground: Custom Forecast & Local Radar : 3.36
# NOAA Weather Radar - Weather Forecast & HD Radar : 3.12
# Weather Live Free - Weather Forecast & Alerts : 2.44
# Storm Radar : 1.56
# QuakeFeed Earthquake Map, Alerts, and News : 0.42
# Moji Weather - Free Weather Forecast : 0.16
# Hurricane by American Red Cross : 0.08
# Forecast Bar : 0.03
# iWeather - World weather forecast : 0.01
# Weather - Radar - Storm with Morecast App : 0.01
# Hurricane Tracker WESH 2 Orlando, Central Florida : 0.01
# FEMA : 0.01
# wetter.com : 0.0
# Yurekuru Call : 0.0
# Weather & Radar : 0.0
# WarnWetter : 0.0
# WRAL Weather Alert : 0.0
# TodayAir : 0.0
# Météo-France : 0.0
# JaxReady : 0.0
# Freddy the Frogcaster's Weather Station : 0.0
# Almanac Long-Range Weather Forecast : 0.0

# %%
# index mapping
# android_free[1] = "Category:": Category the app belongs to
# android_free[3] = "Reviews": Number of user reviews for the app (as when scraped)
# android[0] = "App": Application name
# COMMUNICATION : 992152.3194444445
# SOCIAL : 965830.9872881356
# GAME : 683523.8445475638
display_table(app_percent_of_user_counts(android_free, 1, 'COMMUNICATION', 3, 0))
# Out:
# WhatsApp Messenger : 24.19
# Messenger – Text and Video Chat for Free : 19.82
# UC Browser - Fast Download Private & Secure : 6.2
# BBM - Free Calls & Messages : 4.49
# Viber Messenger : 3.97
# LINE: Free Calls & Messages : 3.78
# Skype - free IM & video calls : 3.67
# Google Chrome: Fast & Secure : 3.37
# Truecaller: Caller ID, SMS spam blocking & Dialer : 2.74
# WeChat : 1.89
# Opera Mini - fast web browser : 1.8
# imo free video calls and chat : 1.67
# Gmail : 1.61
# Yahoo Mail – Stay Organized : 1.47
# UC Browser Mini -Tiny Fast Private & Secure : 1.28
# Hangouts : 1.2
# Telegram : 1.09
# Firefox Browser fast & private : 1.08
# GO SMS Pro - Messenger, Free Themes, Emoji : 1.01
# KakaoTalk: Free Calls & Text : 0.89
# Dolphin Browser - Fast, Private & Adblock🐬 : 0.88
# Opera Browser: Fast and Secure : 0.87
# Who : 0.86
# Kik : 0.86
# CM Browser - Ad Blocker , Fast Download , Privacy : 0.79
# Google Duo - High Quality Video Calls : 0.73
# Messenger Lite: Free Calls & Messages : 0.5
# WhatsCall Free Global Phone Call App & Cheap Calls : 0.4
# DU Browser—Browse fast & fun : 0.4
# Azar : 0.38
# Zalo – Video Call : 0.36
# Mail.Ru - Email App : 0.29
# Android Messages : 0.27
# ICQ — Video Calls & Chat Messenger : 0.24
# imo beta free calls and text : 0.23
# TouchPal Keyboard - Fun Emoji & Android Keyboard : 0.22
# free video calls and chat : 0.21
# Whoscall - Caller ID & Block : 0.19
# Puffin Web Browser : 0.19
# CallApp: Caller ID, Blocker & Phone Call Recorder : 0.17
# Calls Blacklist - Call Blocker : 0.16
# ZenUI Dialer & Contacts : 0.15
# Opera Mini browser beta : 0.14
# chomp SMS : 0.12
# Text SMS : 0.12
# GroupMe : 0.12
# Google Allo : 0.12
# Glide - Video Chat Messenger : 0.12
# myMail – Email for Hotmail, Gmail and Outlook Mail : 0.11
# Discord - Chat for Gamers : 0.11
# Psiphon Pro - The Internet Freedom VPN : 0.1
# Talkray - Free Calls & Texts : 0.09
# GMX Mail : 0.09
# WEB.DE Mail : 0.08
# Voxer Walkie Talkie Messenger : 0.08
# Should I Answer? : 0.08
# Sync.ME – Caller ID & Block : 0.07
# JusTalk - Free Video Calls and Fun Video Chat : 0.07
# Contacts+ : 0.07
# Browser 4G : 0.07
# My Tele2 : 0.06
# Mr. Number-Block calls & spam : 0.06
# Hiya - Caller ID & Block : 0.06
# Google Voice : 0.06
# Free WiFi Connect : 0.06
# Email TypeApp - Mail App : 0.06
# WhatsApp Business : 0.05
# Talkatone: Free Texts, Calls & Phone Number : 0.05
# Portable Wi-Fi hotspot : 0.05
# Free Adblocker Browser - Adblock & Popup Blocker : 0.05
# Newton Mail - Email App for Gmail, Outlook, IMAP : 0.04
# Messenger for SMS : 0.04
# Hangouts Dialer - Call Phones : 0.04
# GO Notifier : 0.04
# Full Screen Caller ID : 0.04
# ExDialer - Dialer & Contacts : 0.04
# Adblock Browser for Android : 0.04
# Your Freedom VPN Client : 0.03
# PHONE for Google Voice & GTalk : 0.03
# MegaFon Dashboard : 0.03
# Lite for Facebook Messenger : 0.03
# K-9 Mail : 0.03
# Calls & Text by Mo+ : 0.03
# Caller ID & Call Block - DU Caller : 0.03
# Call Control - Call Blocker : 0.03
# CM Transfer - Share any files with friends nearby : 0.03
# mail.com mail : 0.02
# Xperia Link™ : 0.02
# Web Browser for Android : 0.02
# Seznam.cz : 0.02
# Orfox: Tor Browser for Android : 0.02
# Ninesky Browser : 0.02
# Contacts : 0.02
# Chrome Dev : 0.02
# CIA - Caller ID & Call Blocker : 0.02
# mysms SMS Text Messaging Sync : 0.01
# Wi-Fi Auto-connect : 0.01
# Web Browser & Explorer : 0.01
# Vonage Mobile® Call Video Text : 0.01
# Virtual Walkie Talkie : 0.01
# Video Caller Id : 0.01
# True Contact - Real Caller ID : 0.01
# TracFone My Account : 0.01
# Tiny Call Confirm : 0.01
# SolMail - All-in-One email app : 0.01
# Skype Lite - Free Video Call & Chat : 0.01
# Safest Call Blocker : 0.01
# RocketDial Dialer & Contacts : 0.01
# Omlet Chat : 0.01
# My magenta : 0.01
# My Vodacom SA : 0.01
# Microsoft Edge : 0.01
# Messaging+ SMS, MMS Free : 0.01
# LokLok: Draw on a Lock Screen : 0.01
# InBrowser - Incognito Browsing : 0.01
# Firefox Focus: The privacy browser : 0.01
# Ear Agent: Super Hearing : 0.01
# Daum Mail - Next Mail : 0.01
# DW Contacts & Phone & Dialer : 0.01
# ClanPlay: Community and Tools for Gamers : 0.01
# Call Free – Free Call : 0.01
# Call Blocker - Blacklist, SMS Blocker : 0.01
# CB Radio Chat - for friends! : 0.01
# Burner - Free Phone Number : 0.01
# Brave Browser: Fast AdBlocker : 0.01
# Bluetooth Auto Connect : 0.01
# AntennaPict β : 0.01
# All Email Providers : 0.01
# 2ndLine - Second Phone Number : 0.01
# tournaments and more.aj.2 : 0.0
# retteMi.ch : 0.0
# mail.co.uk Mail : 0.0
# m:go BiH : 0.0
# love sms good morning : 0.0
# ei : 0.0
# cluster.dk : 0.0
# chat dz : 0.0
# [verify-U] VideoIdent : 0.0
# [EF]ShoutBox : 0.0
# X Browser : 0.0
# WiFi Access Point (hotspot) : 0.0
# Web Browser : 0.0
# WeFi - Free Fast WiFi Connect & Find Wi-Fi Map : 0.0
# U - Webinars, Meetings & Messenger : 0.0
# Traffic signs BD : 0.0
# TownWiFi | Wi-Fi Everywhere : 0.0
# Test Server SMS FA : 0.0
# Talkie - Wi-Fi Calling, Chats, File Sharing : 0.0
# T-Mobile DIGITS : 0.0
# Sat-Fi Voice : 0.0
# Sat-Fi : 0.0
# SW-100.tch by Callstel : 0.0
# SMS Sender - sluzba.cz : 0.0
# Rádio Sol Nascente DF : 0.0
# Ring : 0.0
# ReadyOp DT : 0.0
# QRZ Assistant : 0.0
# Programi podrške EU : 0.0
# Portable Wi-Fi hotspot Free : 0.0
# Pocket Prefix Plus : 0.0
# PlacarTv Futebol Ao Vivo : 0.0
# Oklahoma Ag Co-op Council : 0.0
# Of the wall Arapaho bk : 0.0
# N-Com Wizard : 0.0
# My Vodafone (GR) : 0.0
# My BF App : 0.0
# Morse Code Reader : 0.0
# Mircules DX Cluster Lite : 0.0
# Mail1Click - Secure Mail : 0.0
# MARKET FO : 0.0
# M star Dialer : 0.0
# Lightning Web Browser : 0.0
# Learn Morse Code - G0HYN Learn Morse : 0.0
# Katalogen.ax : 0.0
# K-@ Mail - Email App : 0.0
# K-9 Material (unofficial) : 0.0
# Jazz Wi-Fi : 0.0
# Inbox.eu : 0.0
# IZ2UUF Morse Koch CW : 0.0
# Hyundai CX Conference : 0.0
# Hlášenírozhlasu.cz : 0.0
# HipChat - beta version : 0.0
# Have your say on Europe : 0.0
# Ham Radio Prefixes : 0.0
# Ham DX Cluster & Spots Finder : 0.0
# Goodbox - Mega App : 0.0
# Ghostery Privacy Browser : 0.0
# FreedomPop Messaging Phone/SIM : 0.0
# Free Wi-fi HotspoT : 0.0
# Feel Performer : 0.0
# FP Live : 0.0
# FP Connect : 0.0
# FO STELIA Méaulte : 0.0
# FO SODEXO : 0.0
# FO RCBT : 0.0
# FO PSA Sept-Fons : 0.0
# FO OP St-Nazaire : 0.0
# FO Interim : 0.0
# FO AIRBUS TLSE : 0.0
# FO AIRBUS Nantes : 0.0
# FNH Payment Info : 0.0
# FN Web Radio : 0.0
# FC Browser - Focus Privacy Browser : 0.0
# Everbridge : 0.0
# Ek IRA : 0.0
# Eg Call : 0.0
# EZ Wifi Notification : 0.0
# EU Council : 0.0
# ES-1 : 0.0
# EP RSS Reader : 0.0
# EO Mumbai : 0.0
# EJ messenger : 0.0
# EHiN-FH conferenceapp : 0.0
# Deaf World DW : 0.0
# DMR BrandMeister Tool : 0.0
# DM for WhatsApp : 0.0
# DM Tracker : 0.0
# DM Talk New : 0.0
# DM - The Offical Messaging App : 0.0
# DK TEL Dialer : 0.0
# DK Browser : 0.0
# DG Card : 0.0
# Cy Messenger : 0.0
# Cricket Visual Voicemail : 0.0
# Council Voting Calculator : 0.0
# ClanHQ : 0.0
# Channel 19 : 0.0
# Cb browser : 0.0
# Carpooling FH Hagenberg : 0.0
# Caller ID + : 0.0
# Call Blocker & Blacklist : 0.0
# CW Bluetooth SPP : 0.0
# CW BLE Peripheral Simulator : 0.0
# CS Customizer : 0.0
# CS Browser | #1 & BEST BROWSER : 0.0
# CS Browser Beta : 0.0
# CQ-Mobile : 0.0
# CQ-Alert : 0.0
# CK Call NEW : 0.0
# CJ DVD Rentals : 0.0
# CJ Browser - Fast & Private : 0.0
# CF Chat: Connecting Friends : 0.0
# CB On Mobile : 0.0
# C W Browser : 0.0
# BlueDV AMBE : 0.0
# Best Browser BD social networking : 0.0
# Best Auto Call Recorder Free : 0.0
# Bee'ah Employee App : 0.0
# Baby Monitor AV : 0.0
# BV : 0.0
# BT One Voice mobile access : 0.0
# BT One Phone Mobile App : 0.0
# BT Messenger : 0.0
# BT MeetMe with Dolby Voice : 0.0
# BS-Mobile : 0.0
# BQ Partners : 0.0
# BN MALLORCA Radio : 0.0
# BK Chat : 0.0
# BJ - Confidential : 0.0
# BH Mail : 0.0
# BF Browser by Betfilter - Stop Gambling Today! : 0.0
# BD Live Call : 0.0
# BD Internet Packages (Updated) : 0.0
# BD Dialer : 0.0
# BD Data Plan (3G & 4G) : 0.0
# BBMoji - Your personalized BBM Stickers : 0.0
# BA SALES : 0.0
# AudioBT: BT audio GPS/SMS/Text : 0.0
# Antillean Gold Telegram (original version) : 0.0
# Amadeus GR & CY : 0.0
# Aj.Petra : 0.0
# Adblock Plus for Samsung Internet - Browse safe. : 0.0
# Ad Blocker Turbo - Adblocker Browser : 0.0
# Access Point Names : 0.0
# AZ Browser. Private & Download : 0.0
# AW - free video calls and chat : 0.0
# AV Phone : 0.0
# AU Call Blocker - Block Unwanted Calls Texts 2018 : 0.0
# ATC Unico BS : 0.0
# AT&T Visual Voicemail : 0.0
# AT&T Messages for Tablet : 0.0
# AT&T Call Protect : 0.0
# AK Phone : 0.0
# AG Contacts, Lite edition : 0.0
# AC-BL : 0.0
# 3G DZ Configuration : 0.0
# /u/app : 0.0

# %%
## Why is Twitter not in Social?
for app in android_free:
    if app[0] == 'Twitter':
        print(app)
        break

for app in ios_free:
    if app[1] == 'Twitter':
        print(app)
        break
# Out:
# ['Twitter', 'NEWS_AND_MAGAZINES', '4.3', '11667403', 'Varies with device', '500,000,000+', 'Free', '0', 'Mature 17+', 'News & Magazines', 'August 6, 2018', 'Varies with device', 'Varies with device']
# ['333903271', 'Twitter', '210569216', 'USD', '0.0', '354058', '452', '3.5', '4.0', '6.79.1', '17+', 'News', '37', '2', '33', '1']

# %% [markdown]
# Above, we checked the top 3 genres for both datasets to see if specific apps are skewing the averages.
#
# For iOS - both Navigation and Reference are dominated by one or two apps accounting for over 70% of the user ratings.
#
# For both iOS and Android, the combination of Facebook + Instagram make up over 50% of the user ratings for Social. I was surpised to not see Twitter in that list, but it turns out that both stores categorize it as "News".
#
# On Android, the only top 3 grenre that didn't show skewing was Games.

# %% [markdown]
# ### Remove skewing apps and check average ratings again
#
# Let's remove some of the above apps that skew averages and check the genre ratings again.

# %%
# iOS skewing apps:
# Waze - GPS Navigation, Maps & Real-time Traffic : 66.8
# Google Maps - Navigation & Transit : 29.99
# Bible : 73.09
# Dictionary.com Dictionary & Thesaurus : 14.83
# Facebook : 39.23
# Pinterest : 14.0
app_delete_list_names = ['Waze - GPS Navigation, Maps & Real-time Traffic'
                         ,'Google Maps - Navigation & Transit'
                         ,'Bible'
                         ,'Dictionary.com Dictionary & Thesaurus'
                         ,'Facebook'
                         ,'Pinterest']

ios_no_skew = []
# ios_free[1] = "track_name": App Name
for row in ios_free:
    if row[1] not in app_delete_list_names:
        ios_no_skew.append(row)

print('Length of ios_free: ', len(ios_free))
print('Expected length of ios_no_skew: ', len(ios_free) - len(app_delete_list_names))
print('Length of ios_no_skew: ', len(ios_no_skew))
# Out:
# Length of ios_free:  3263
# Expected length of ios_no_skew:  3257
# Length of ios_no_skew:  3257

# %%
# android skewing apps:
# Facebook : 34.29
# Instagram : 29.21
# WhatsApp Messenger : 24.19
# Messenger – Text and Video Chat for Free : 19.82
app_delete_list_names = ['Facebook'
                         ,'Instagram'
                         ,'WhatsApp Messenger'
                         ,'Messenger – Text and Video Chat for Free'
                        ]

android_no_skew = []
# android[0] = "App": Application name
for row in android_free:
    if row[0] not in app_delete_list_names:
        android_no_skew.append(row)

print('Length of android_free: ', len(android_free))
print('Expected length of android_no_skew: ', len(android_free) - len(app_delete_list_names))
print('Length of android_no_skew: ', len(android_no_skew))
# Out:
# Length of android_free:  8882
# Expected length of android_no_skew:  8878
# Length of android_no_skew:  8878

# %%
#recheck average ratings
# index mapping
# ios_free[11] = "prime_genre": Primary Genre
# ios_free[5] = "rating_count_tot": User Rating counts (for all version)
display_table(avg_user_counts(ios_no_skew, 11, 5, freq_table(ios_no_skew, 11)))
# Out:
# Music : 57326.530303030304
# Weather : 52279.892857142855
# Book : 37107.933333333334
# Social Networking : 34437.854368932036
# Finance : 31468.027777777777
# Food & Drink : 28891.033333333333
# Photo & Video : 28090.413580246914
# Travel : 27551.219512195123
# Shopping : 26293.732558139534
# Health & Fitness : 23298.015384615384
# Sports : 23008.898550724636
# Games : 22572.40539112051
# News : 20765.113636363636
# Productivity : 20659.491228070176
# Utilities : 18467.256097560974
# Lifestyle : 15872.924528301886
# Entertainment : 13602.141221374046
# Reference : 10186.9375
# Business : 7491.117647058823
# Education : 7003.983050847458
# Navigation : 4146.25
# Catalogs : 4004.0
# Medical : 525.4285714285714

# %%
#recheck average ratings
# index mapping
# android_free[1] = "Category:": Category the app belongs to
# android_free[3] = "Reviews": Number of user reviews for the app (as when scraped)
display_table(avg_user_counts(android_no_skew, 1, 3, freq_table(android_no_skew, 1)))
# Out:
# GAME : 682733.6234067207
# COMMUNICATION : 561311.350877193
# VIDEO_PLAYERS : 425350.08176100627
# PHOTOGRAPHY : 404081.3754789272
# SOCIAL : 355557.0982905983
# TOOLS : 305732.8973333333
# ENTERTAINMENT : 301752.24705882353
# SHOPPING : 223887.34673366835
# PERSONALIZATION : 180508.3525423729
# WEATHER : 171250.77464788733
# PRODUCTIVITY : 160170.91040462427
# MAPS_AND_NAVIGATION : 141775.68
# TRAVEL_AND_LOCAL : 129484.42512077295
# SPORTS : 116938.6146179402
# FAMILY : 112837.6694411415
# NEWS_AND_MAGAZINES : 92343.584
# BOOKS_AND_REFERENCE : 87087.75520833333
# HEALTH_AND_FITNESS : 78094.9706959707
# FOOD_AND_DRINK : 57478.79090909091
# EDUCATION : 56293.09708737864
# COMICS : 42585.61818181818
# FINANCE : 38535.8993902439
# LIFESTYLE : 33767.031518624644
# HOUSE_AND_HOME : 26435.465753424658
# ART_AND_DESIGN : 24699.42105263158
# BUSINESS : 24181.105392156864
# DATING : 21953.272727272728
# PARENTING : 16378.706896551725
# AUTO_AND_VEHICLES : 14140.280487804877
# LIBRARIES_AND_DEMO : 10925.807228915663
# BEAUTY : 7476.226415094339
# MEDICAL : 3730.1533546325877
# EVENTS : 2555.84126984127

# %% [markdown]
# After removing the skewing apps from the top three genres by user counts, we see iOS has all new top three genres and Android had `GAME` move to the top.
#
# On iOS, `Games` is in the middle of the pack, but let's check this genre for skewing in both data sets.
#
# ### Closer look at Games genre

# %%
print('===ios-Games===')
display_table(app_percent_of_user_counts(ios_free, 11, 'Games', 5, 1))
# Out:
# ===ios-Games===
# Clash of Clans : 4.99
# Temple Run : 4.04
# Candy Crush Saga : 2.25
# Angry Birds : 1.93
# Subway Surfers : 1.65
# Solitaire : 1.59
# CSR Racing : 1.59
# Crossy Road - Endless Arcade Hopper : 1.57
# Injustice: Gods Among Us : 1.43
# Hay Day : 1.33
# PAC-MAN : 1.19
# DragonVale : 1.18
# Head Soccer : 1.13
# Despicable Me: Minion Rush : 1.09
# The Sims™ FreePlay : 1.05
# Sonic Dash : 0.98
# 8 Ball Pool™ : 0.98
# Tiny Tower - Free City Building : 0.97
# Jetpack Joyride : 0.95
# Bike Race - Top Motorcycle Racing Games : 0.95
# Kim Kardashian: Hollywood : 0.93
# WordBrain : 0.92
# Trivia Crack : 0.92
# Sniper 3D Assassin: Shoot to Kill Gun Game : 0.91
# Flow Free : 0.88
# Geometry Dash Lite : 0.87
# ▻Sudoku : 0.84
# Fruit Ninja® : 0.77
# Pixel Gun 3D : 0.71
# Temple Run 2 : 0.69
# My Horse : 0.69
# Word Cookies! : 0.67
# Dragon City Mobile : 0.65
# The Simpsons™: Tapped Out : 0.64
# Plants vs. Zombies™ 2 : 0.63
# Clash Royale : 0.63
# Pokémon GO : 0.6
# CSR Racing 2 : 0.6
# Star Wars™: Commander : 0.59
# Boom Beach : 0.57
# MARVEL Contest of Champions : 0.55
# MADDEN NFL Mobile : 0.54
# Bejeweled Blitz : 0.52
# Can You Escape : 0.51
# Fallout Shelter : 0.47
# SimCity BuildIt : 0.46
# Real Basketball : 0.46
# Pictoword: Fun 2 Pics Guess What's the Word Trivia : 0.44
# Magic Jigsaw Puzzles : 0.44
# Glow Hockey 2 FREE : 0.44
# Farm Heroes Saga : 0.44
# Beer Pong Game : 0.44
# Asphalt 8: Airborne : 0.44
# ROBLOX : 0.43
# Bejeweled Classic : 0.43
# Deer Hunter Classic : 0.42
# Daily Celebrity Crossword : 0.42
# Call of Duty®: Heroes : 0.42
# Blackjack by MobilityWare : 0.42
# AdVenture Capitalist : 0.42
# Agar.io : 0.41
# Piano Tiles (Don't Tap The White Tile) : 0.4
# Angry Birds Rio : 0.4
# The Secret Society® - Hidden Mystery : 0.39
# Real Racing 3 : 0.39
# Words with Friends – Best Word Game : 0.38
# Highway Rider : 0.38
# aa : 0.37
# Episode - Choose Your Story : 0.37
# Bowmasters - Top Multiplayer Bowman Archery Game : 0.37
# 2048 : 0.37
# Jurassic World™: The Game : 0.35
# Dumb Ways to Die : 0.35
# Color Switch : 0.34
# Two Dots : 0.33
# Racing Penguin Free - Top Flying and Diving Game : 0.33
# Iron Force : 0.33
# Summoners War : 0.32
# Jigsaw Puzzle : 0.32
# Sniper Shooter: Gun Shooting Games : 0.31
# My Singing Monsters : 0.31
# Candy Crush Soda Saga : 0.31
# Spider Solitaire Free by MobilityWare : 0.3
# Smash Hit : 0.3
# ▻Solitaire : 0.29
# Tetris® Blitz : 0.29
# Star Wars™: Galaxy of Heroes : 0.29
# My Talking Tom : 0.29
# Clumsy Ninja : 0.29
# Bubble Mania™ : 0.29
# Geometry Dash Meltdown : 0.28
# Village Life: Love, Marriage and Babies : 0.27
# Sky Burger - Build & Match Food Free : 0.27
# MORTAL KOMBAT X : 0.27
# Big Fish Casino – Best Vegas Slot Machines & Games : 0.27
# Beat the Boss 2 : 0.27
# Monster Legends RPG - War, Fight & Heroes Game : 0.26
# Fairway Solitaire Blast : 0.26
# Angry Birds 2 : 0.26
# ⋆Solitaire : 0.25
# slither.io : 0.25
# Hill Climb Racing : 0.25
# Game of War - Fire Age : 0.25
# Cooking Fever : 0.25
# Angry Birds Transformers : 0.25
# ZigZag : 0.24
# Family Guy: The Quest for Stuff : 0.24
# DoubleDown Casino & Slots  – Vegas Slot Machines! : 0.24
# War Robots : 0.23
# Shadow Fight 2 : 0.23
# MLB.com Home Run Derby 17 : 0.23
# Angry Birds Space : 0.22
# Tap Titans : 0.21
# Super Mario Run : 0.21
# PewDiePie's Tuber Simulator : 0.21
# Angry Birds HD : 0.21
# Score! Hero : 0.2
# Hungry Shark Evolution : 0.2
# Angry Birds Epic RPG : 0.2
# Township : 0.19
# Godus : 0.19
# Egg, Inc. : 0.19
# Candy Blast Mania : 0.19
# Blackbox - think outside the box : 0.19
# 4 Pics 1 Word : 0.19
# Toy Blast : 0.18
# Nyan Cat: Lost In Space : 0.18
# Daddy Long Legs : 0.18
# DEAD TRIGGER : 0.18
# Covet Fashion - The Game for Dresses & Shopping : 0.18
# Block Craft 3D: Building Simulator Game For Free : 0.18
# Angry Birds Seasons HD : 0.18
# Angry Birds Go! : 0.18
# QuizUp™ : 0.17
# Bejeweled Classic HD : 0.17
# UNO ™ & Friends : 0.16
# Trigger Fist : 0.16
# Stack : 0.16
# Slots - Pharaoh's Way : 0.16
# Bloons TD Battles : 0.16
# Angry Birds Rio HD : 0.16
# WordBubbles! : 0.15
# Solitaire· : 0.15
# MY LITTLE PONY: Magic Princess Quests : 0.15
# MARVEL Spider-Man Unlimited : 0.15
# LINE: Disney Tsum Tsum : 0.15
# Dream League Soccer 2017 : 0.15
# Criminal Case : 0.15
# Ace Fishing: Wild Catch : 0.15
# Viva™ Slots Las Vegas Classic Casino Games : 0.14
# Logos Quiz -Guess the most famous brands, new fun! : 0.14
# Happy Wheels : 0.14
# Gummy Drop! – A Match 3 Puzzle Game : 0.14
# Flight Pilot Simulator 3D: Flying Game For Free : 0.14
# Cascade: Fun Spin and Match Puzzle Game : 0.14
# Bowling King : 0.14
# WordWhizzle : 0.13
# Racing Rivals : 0.13
# Piano Tiles 2™(Don't Tap The White Tile 2) : 0.13
# NYTimes Crossword - Daily Word Puzzle Game : 0.13
# My Talking Angela : 0.13
# My Boo - Virtual Pet with Mini Games for Kids : 0.13
# Kendall and Kylie : 0.13
# Evil Apples: A Filthy Adult Card & Party Game : 0.13
# Bingo!™ : 0.13
# 1010! : 0.13
# WordWhizzle Search : 0.12
# WGT Golf Game by Topgolf : 0.12
# Smashy Road: Wanted : 0.12
# Frozen Free Fall : 0.12
# Cookie Jam : 0.12
# Tricky Test 2™: Genius Brain? : 0.11
# Super Stickman Golf 2 : 0.11
# Seekers Notes: Hidden Mystery : 0.11
# Modern Combat 5 : The Multiplayer eSports Shooter : 0.11
# Mahjong Journey® : 0.11
# Jelly Jump : 0.11
# Gardenscapes - New Acres : 0.11
# Gangstar Vegas : 0.11
# Close Up Pics Quiz - Guess the Word Trivia Games : 0.11
# Castle Clash: Brave Squads : 0.11
# Alice in the Mirrors of Albion: Hidden object game : 0.11
# World of Tanks Blitz : 0.1
# Wooden Block Puzzle - Wood jigsaw fit 1010 matrix : 0.1
# The Sandbox - Building & Crafting a Pixel World! : 0.1
# Soccer Stars™ : 0.1
# Real Steel World Robot Boxing : 0.1
# Pearl's Peril - Hidden Object Adventures : 0.1
# Panda Pop : 0.1
# NBA LIVE Mobile Basketball : 0.1
# Hangman. : 0.1
# Flippy Bottle Extreme! - Marker Flip Tricky 2K16 : 0.1
# Disney Emoji Blitz : 0.1
# CSR Classics : 0.1
# Blitz Brigade: Multiplayer FPS shooter online! : 0.1
# Billionaire – Business Capitalist Tycoon! : 0.1
# Zombie Frontier 3 – Top Zombie Shooting Game : 0.09
# YAHTZEE® With Buddies: The Classic Dice Game : 0.09
# Unison League : 0.09
# Lep's World Free - platformer games : 0.09
# Jigsaw Puzzle Collection HD : 0.09
# Hidden City®: Mystery of Shadows : 0.09
# Gin Rummy Plus - Multiplayer Online Card Game : 0.09
# Fishdom : 0.09
# Disney Crossy Road : 0.09
# Best Fiends : 0.09
# Angry Birds Space HD : 0.09
# Yu-Gi-Oh! Duel Links : 0.08
# Timberman : 0.08
# Solitaire TriPeaks: Classic Card Game : 0.08
# Need for Speed™ No Limits : 0.08
# Mr Jump : 0.08
# Jenga : 0.08
# Into the Dead : 0.08
# Hill Climb Racing 2 : 0.08
# Hearthstone : 0.08
# Fishing Kings Free+ : 0.08
# Egg! : 0.08
# Dragon Mania Legends: Dragon Breeding Game : 0.08
# Cooking Dash™ : 0.08
# Choices: Stories You Play : 0.08
# Candy Crush Jelly Saga : 0.08
# Angry Birds Star Wars II : 0.08
# Angry Birds Star Wars : 0.08
# Angry Birds POP! - Bubble Shooter : 0.08
# Zombie Tsunami : 0.07
# World Chef: Restaurant & Cooking Game : 0.07
# WWE Immortals : 0.07
# Twist : 0.07
# Trials Frontier : 0.07
# Stick Hero : 0.07
# Rolling Sky : 0.07
# Pop the Lock : 0.07
# Neko Atsume: Kitty Collector : 0.07
# Megapolis : 0.07
# Fun Run 2 - Multiplayer Race : 0.07
# FINAL FANTASY BRAVE EXVIUS : 0.07
# Extreme Car Driving Simulator Free : 0.07
# Dude Perfect 2 : 0.07
# Doodle Jump FREE - BE WARNED: Insanely addictive : 0.07
# Dog Simulator 2015 : 0.07
# Crazy Kitchen : 0.07
# Blossom Blast Saga - Fun Flower Match & Grow Game : 0.07
# Block! Hexa Puzzle : 0.07
# Basketball Stars™ : 0.07
# Arrow Ambush : 0.07
# 100 Balls : 0.07
# Words Crush: Hidden Words! : 0.06
# Wizard of OZ: Magic Match : 0.06
# War Dragons : 0.06
# Vainglory : 0.06
# Turbo Dismount® : 0.06
# Tap Sports Baseball 2016 : 0.06
# Tank War - Geometry Go Shot Color Dot.IO : 0.06
# Survivors: the Quest® : 0.06
# SMILE Inc. : 0.06
# Royal Revolt 2 – Defend Your Castle : 0.06
# Paper.io : 0.06
# N.O.V.A. 3: Freedom Edition - Near Orbit Vanguard Alliance game : 0.06
# My Cafe: Recipes & Stories - World Restaurant Game : 0.06
# Mobile Strike : 0.06
# Make It Rain: The Love of Money : 0.06
# Looney Tunes Dash! : 0.06
# Hungry Shark World : 0.06
# Driving School 2016 : 0.06
# Disco Zoo : 0.06
# Cops N Robbers (FPS) - Block Survival Multiplayer : 0.06
# Clash of Kings - CoK : 0.06
# Batman: Arkham Origins : 0.06
# Bad Piggies : 0.06
# Assassin's Creed Pirates : 0.06
# Animal Jam - Play Wild! : 0.06
# Angry Birds Friends : 0.06
# Angry Birds Blast : 0.06
# iGun Pro HD - The Original Gun Application : 0.05
# Where's My Water? 2 : 0.05
# Vlogger Go Viral - Clicker Game & Vlog Simulator : 0.05
# VS. Racing 2 : 0.05
# Traffic Racer : 0.05
# The Walking Dead: No Man's Land : 0.05
# Sugar Smash: Book of Life : 0.05
# Spinny Circle : 0.05
# Solitaire Classic Card Game™ : 0.05
# RollerCoaster Tycoon® 4 Mobile™ : 0.05
# Roll the Ball™ - slide puzzle : 0.05
# Robot Unicorn Attack 2 : 0.05
# Restaurant DASH with Gordon Ramsay : 0.05
# Paradise Bay : 0.05
# PAC-MAN 256 - Endless Arcade Maze : 0.05
# Minecraft: Story Mode : 0.05
# MONOPOLY Bingo! : 0.05
# MARVEL Future Fight : 0.05
# LEGO® Star Wars™:  The Complete Saga : 0.05
# King of Thieves : 0.05
# Kill Shot Bravo : 0.05
# Juice Jam : 0.05
# Jelly Splash : 0.05
# Inside Out Thought Bubbles : 0.05
# Hot Shot Slots Games – Vegas Casino Slot Machines : 0.05
# Heart of Vegas Slots – Casino Slot Machine Games : 0.05
# Gods of Olympus : 0.05
# Empires & Allies : 0.05
# EA SPORTS™ UFC® : 0.05
# Dungeon Hunter 5 - Multiplayer RPG on iOS : 0.05
# Dungeon Boss : 0.05
# Drive Ahead! : 0.05
# Design Home : 0.05
# Crazy Taxi™ City Rush : 0.05
# Colorfly : Coloring Book for Adults - Free Games : 0.05
# Century City : 0.05
# Castle Crush: Epic Strategy Game : 0.05
# Angry Birds Star Wars HD : 0.05
# Amazing Thief : 0.05
# 100 PICS Quiz - guess the picture trivia games : 0.05
# Zombie Catchers : 0.04
# Zombie Castaways : 0.04
# X-War: Clash of Zombies : 0.04
# Willy Wonka Slots: Vegas Casino Slot Machines : 0.04
# Warhammer 40,000: Freeblade : 0.04
# The Walking Dead: Road to Survival - Strategy Game : 0.04
# The Silent Age : 0.04
# The Line Zen : 0.04
# Tap Tap Fish - Abyssrium : 0.04
# Talking Tom Gold Run: Fun & Endless Running Game : 0.04
# Swamp Attack : 0.04
# Sonic CD : 0.04
# Shooty Skies - Endless Arcade Flyer : 0.04
# Rodeo Stampede - Sky Zoo Safari : 0.04
# Racing in Car : 0.04
# Plants vs. Zombies™ Heroes : 0.04
# Ninja Kid Run VR: Runner & Racing Games For Free : 0.04
# Merged! : 0.04
# MARVEL Avengers Academy : 0.04
# Letter Soup - Word Game : 0.04
# Kitchen Scramble: Cooking Game : 0.04
# Hovercraft: Takedown - Custom Combat Cars : 0.04
# Head Basketball : 0.04
# Forge of Empires : 0.04
# Flip Diving : 0.04
# Flappy Golf : 0.04
# FarmVille: Tropic Escape - Harvest in Paradise : 0.04
# Farm Heroes Super Saga: Match, Collect and Grow! : 0.04
# FIFA Mobile Soccer : 0.04
# Disney Magic Kingdoms : 0.04
# Dawn of Titans : 0.04
# DC Legends : 0.04
# Cupcake Mania™ : 0.04
# Charades!™ : 0.04
# Bingo Pop : 0.04
# Bad Piggies HD : 0.04
# Animation Throwdown: The Quest for Cards : 0.04
# 100! Block Puzzle - Color jigsaw 10x10 board game : 0.04
# my KONAMI Slots - Vegas Casino Slot Machine Games : 0.03
# Zombie Highway 2 : 0.03
# Wheel of Fortune: Game Show Word Puzzles : 0.03
# War Machines: 3D Multiplayer Tank Shooting Game : 0.03
# WWE SuperCard : 0.03
# Transformers: Earth Wars : 0.03
# Traffic Rider : 0.03
# Top Eleven 2017 - Be a Soccer Manager : 0.03
# The Trail : 0.03
# Teenage Mutant Ninja Turtles: Legends : 0.03
# Tap Tycoon - Country vs Country : 0.03
# Tap Tap Dash : 0.03
# Sunken Secrets : 0.03
# Steppy Pants : 0.03
# Solitaire Ⓞ : 0.03
# Snapimals: Discover & Snap Amazing & Cute Animals! : 0.03
# Snakeio : 0.03
# Slots - Huuuge Casino: Slot Machines : 0.03
# Skyline Skaters : 0.03
# Six! : 0.03
# Rival Fire : 0.03
# Rick and Morty: Pocket Mortys : 0.03
# Rayman Adventures : 0.03
# Pokémon TCG Online : 0.03
# Phoenix HD : 0.03
# Peggle Blast : 0.03
# Pakka Pets Village - Build a Cute Virtual Pet Town : 0.03
# Mobile Legends: Bang bang : 0.03
# MMX Racing : 0.03
# MMX Hill Dash — Off-Road Racing : 0.03
# Lep's World 3 : 0.03
# KleptoCats : 0.03
# Hovercraft - Build Fly Retry : 0.03
# Hop : 0.03
# Haunted Halloween Escape : 0.03
# Fruit Nibblers : 0.03
# Football Clicker : 0.03
# Flick Kick Football Legends : 0.03
# Farm Story 2™ : 0.03
# Fair Food Maker Game - Make Yummy Carnival Treats : 0.03
# Extreme Fishing 2 Free : 0.03
# Dumb Ways to Die 2: The Games : 0.03
# Dots: A Game About Connecting : 0.03
# Dots & Co: A New Puzzle Adventure : 0.03
# Dictator: Outbreak : 0.03
# Deer Hunter 2017 : 0.03
# Churchill Solitaire - World War Card Game : 0.03
# CLUE Bingo : 0.03
# Bottle Flip 2k16 : 0.03
# Block Сity Wars: game and skin export to minecraft : 0.03
# Bee Brilliant : 0.03
# BIG WIN Basketball : 0.03
# Arrow : 0.03
# 94% : 0.03
# diep.io : 0.02
# Zen Pinball : 0.02
# Would You Rather? : 0.02
# Word Search Colorful : 0.02
# Weed Firm: RePlanted : 0.02
# War Tortoise : 0.02
# Vikings: War of Clans : 0.02
# Touchdown Hero : 0.02
# Tomb of the Mask : 0.02
# Tinker Island: Survival Adventure : 0.02
# The Impossible Letter Game : 0.02
# Tap Titans 2 : 0.02
# Tank.IO War - Free Tank games of snake : 0.02
# Tactile Wars : 0.02
# Swing : 0.02
# Super Cat Tales : 0.02
# Suicide Squad: Special Ops : 0.02
# Stupid Zombies 3 : 0.02
# Stop - Fun Categories Word Game : 0.02
# StickyBalls Deluxe - Addicting Fall Down Game : 0.02
# Steve - The Jumping Dinosaur Widget Arcade Game : 0.02
# Spin It Rich! Casino Slots: Free Slot Machines : 0.02
# Sonic & All-Stars Racing Transformed : 0.02
# SongPop 2 - Guess The Song : 0.02
# Solitaire Deluxe® Social - Classic, Spider, more : 0.02
# Soccer Star 2016 World Legend : 0.02
# Sniper Fury: Fun Mobile Shooter Game : 0.02
# Snake Slither Run - Hungry Worm Eat Color Dot : 0.02
# Smashy City : 0.02
# Smash Monsters - City Rampage : 0.02
# Slots: DoubleUp Free Slot Games - Slot Machines : 0.02
# Sky Force Reloaded : 0.02
# Run!!! : 0.02
# RoverCraft Space Racing : 0.02
# Restaurant Story 2 : 0.02
# RPG AVABEL ONLINE : 0.02
# Quick Hit Slots – Casino Slot Machines Games : 0.02
# Pokémon Duel : 0.02
# Pineapple Pen : 0.02
# Pet Buddies HD : 0.02
# POP! Slots – Las Vegas Casino Slot Machine Games : 0.02
# One More Line : 0.02
# Olympus Rising : 0.02
# Nonstop Knight : 0.02
# No Brakes : 0.02
# NARUTO SHIPPUDEN: Ultimate Ninja Blazing : 0.02
# Mystic Messenger : 0.02
# My Singing Monsters: Dawn of Fire : 0.02
# My Emma :) : 0.02
# Mr. Crab : 0.02
# Monster Super League : 0.02
# Mini Golf Stars! Retro Golf Game : 0.02
# Mimitos Virtual cat with minigames : 0.02
# Mekorama : 0.02
# Mahjong Treasure Quest : 0.02
# Mahjong Classic Board Game : 0.02
# Lords Mobile : 0.02
# Kids Doodle - Movie Kids Color & Draw : 0.02
# Hungry Babies Mania : 0.02
# High 5 Casino - Real Vegas Slots! : 0.02
# Hide N Seek : Mini Multiplayer Game : 0.02
# Hidden Objects: Mystery Society: Solve Crime Cases : 0.02
# Genies & Gems : 0.02
# Galaxy on Fire 3 - Manticore : 0.02
# Futurama: Game of Drones : 0.02
# Fresh Tracks Snowboarding : 0.02
# Fit The Fat 2 : 0.02
# Fist of Fury : 0.02
# Fantasy Forest Story: Land Before Dragons : 0.02
# DragonSoul RPG : 0.02
# Diggy's Adventure : 0.02
# Despicable Bear - Top Beat Action Game : 0.02
# Dear Diary - Interactive Story : 0.02
# Dan The Man (Retro Action Platformer) : 0.02
# Crazy Taxi : 0.02
# Crafty Candy - Match 3 Puzzle Game : 0.02
# Clicker Heroes : 0.02
# Clash of Lords 2: New Age : 0.02
# Christmas Food Fever Cooking Maker Kids Games : 0.02
# Christmas Dentist Doctor Kid Games (Girls & Boys) : 0.02
# Cat Kitty Kitten Coloring Pages - Free Girl Games : 0.02
# Burrito Bison: Launcha Libre : 0.02
# Bullet Force : 0.02
# Builder Buddies: 3D City Building Simulator : 0.02
# Bud Farm: Grass Roots : 0.02
# Best Fiends Forever : 0.02
# Bejeweled Stars : 0.02
# Batman: Arkham Underworld : 0.02
# BBTAN by 111% : 0.02
# Archery King : 0.02
# Afterpulse : 0.02
# Zig Zag Boom : 0.01
# YO-KAI WATCH Wibble Wobble : 0.01
# World of Cubes Survival Craft : 0.01
# World Craft HD : 0.01
# Wordalot – Picture Crossword : 0.01
# WordBrain 2 : 0.01
# Word Trek  - WordTrek Brain game & Word puzzles : 0.01
# White Tiles 4: Piano Master (All mini games in 1) : 0.01
# Wheel of Fortune Slots Casino with Vanna White : 0.01
# Weed Firm 2: Back To College : 0.01
# Water Bottle Flip Challenge 2 : 0.01
# Warrior Balls : 0.01
# War Commander: Rogue Assault : 0.01
# VOEZ : 0.01
# UNKILLED: MULTIPLAYER ZOMBIE SURVIVAL SHOOTER GAME : 0.01
# Twisty Wheel : 0.01
# Twisty Arrow - Shoot the Circle Wheel : 0.01
# Twin Moons Society™: Hidden Mystery : 0.01
# Trump Dump ⁢ : 0.01
# Troll Face Quest Video Memes : 0.01
# Trivia Crack Kingdoms : 0.01
# Trial Xtreme 4 : 0.01
# Total War Battles: KINGDOM : 0.01
# Torque Burnout : 0.01
# Tiny Miners : 0.01
# Thumb Drift - Furious One Touch Car Racing : 0.01
# The Sandbox Evolution - Craft a 2D Pixel Universe : 0.01
# The Quest Keeper : 0.01
# The Paranormal Society™: Hidden Adventure : 0.01
# The Maze Runner ™ : 0.01
# The Last Vikings : 0.01
# The Battle of Polytopia : 0.01
# Tennis Champs Returns : 0.01
# Taxi Sim 2016 : 0.01
# Taps to Riches : 0.01
# Tap Smiths : 0.01
# Tankio - Battle Arena : 0.01
# Tank.io war - Free Classic Tank games : 0.01
# Talking Tom Jetski : 0.01
# Talking Tom Bubble Shooter : 0.01
# TETRIS® FREE : 0.01
# Super Atomic : 0.01
# Stupid Test! : 0.01
# Stormfall: Rise of Balur : 0.01
# Star Trek ® - Wrath of Gems : 0.01
# Star Trek Timelines : 0.01
# Spellspire : 0.01
# Sonic Dash 2: Sonic Boom : 0.01
# Solitaire ∞ : 0.01
# Soda Dungeon : 0.01
# Soccer Clicker : 0.01
# Smashy Road: Arena : 0.01
# Slots: VIP Deluxe Slots Machines - Free Slot Games : 0.01
# Slots: Hot Vegas Slot Machines - Free Slot Games : 0.01
# Slots - Lucky Win Casino Games & Slot Machines : 0.01
# Sling Kong : 0.01
# Slash Mobs : 0.01
# Slam Dunk Basketball 2 - Play & Do Good : 0.01
# Skylanders Battlecast : 0.01
# Sky Whale - a Game Shakers App : 0.01
# Skiing Yeti Mountain : 0.01
# Simulator Hoverboard : 0.01
# Shuffle Cats : 0.01
# Shopping Mall Girl - Dress Up & Style Game : 0.01
# Shopkins: Chef Club : 0.01
# Shopkins World! : 0.01
# Sea Hero Quest : 0.01
# Scrubby Dubby Saga : 0.01
# School of Chaos Online MMORPG : 0.01
# Sandstorm: Pirate Wars : 0.01
# STAR WARS™: FORCE COLLECTION : 0.01
# Round Balls : 0.01
# Rolling Snake.io - Worm IO Multiplayer Online Slither War Game - Free Agar Skins Version : 0.01
# Rival Stars Basketball : 0.01
# Risky Road : 0.01
# Real Fishing 3D Free : 0.01
# Real Boxing 2 ROCKY : 0.01
# RISK: Global Domination : 0.01
# Princess Salon™ - Girls Makeup, Dressup and Makeover Games : 0.01
# Pou : 0.01
# PolitiCats: Awesome Clicker Game : 0.01
# Pokémon Shuffle Mobile : 0.01
# Pocket Politics : 0.01
# Plants vs. Zombies FREE HD : 0.01
# Pixel Starships™ : 8Bit MMORPG : 0.01
# Pixel Car Racer : 0.01
# Pirate Power : 0.01
# Pinchworm : 0.01
# PinOut! : 0.01
# Peanuts: Snoopy's Town Tale : 0.01
# Pancake – The Game : 0.01
# PKTBALL - Endless Arcade Smash Sport : 0.01
# PES CLUB MANAGER : 0.01
# Oz: Broken Kingdom™ : 0.01
# Order & Chaos 2: 3D MMO RPG Online Game : 0.01
# Online Head Ball : 0.01
# OPUS: The Day We Found Earth : 0.01
# Nono Islands : 0.01
# Nom Cat - Endless feeding frenzy arcade game : 0.01
# Naughty Kitties : 0.01
# Narcos: Cartel Wars : 0.01
# NCIS: Hidden Crimes : 0.01
# My Bowling 3D : 0.01
# Monster Girls Creator Catch em for Pokémon fans : 0.01
# Monster Craft GO - Find and Catch pixelmon CarToon : 0.01
# Mine Blitz : 0.01
# Microsoft Solitaire Collection : 0.01
# McPlay™ : 0.01
# Mars: Mars : 0.01
# Make7! Hexa Puzzle : 0.01
# Make More! : 0.01
# Mahjong Solitaire Star! Your Favorite Game! : 0.01
# Magic Tiles : Music Maker - Don't Touch the White : 0.01
# Magic Rush: Heroes : 0.01
# MOBIUS FINAL FANTASY : 0.01
# MLB 9 Innings 17 : 0.01
# Love and Hip Hop The Game : 0.01
# Loop Drive 2 : 0.01
# Lollipop: Sweet Taste Match3 : 0.01
# Legacy of Discord - Furious Wings : 0.01
# Leap Day : 0.01
# League of War: Mercenaries : 0.01
# Last Empire – War Z: Zombie Strategy Game : 0.01
# Lara Croft: Relic Run : 0.01
# Land Sliders : 0.01
# LEGO® Star Wars™: The Force Awakens : 0.01
# LEGO® Juniors Create & Cruise : 0.01
# Kritika: The White Knights : 0.01
# King of Avalon: Dragon Warfare : 0.01
# Kids Shave Salon Spa Games (Boys & Girls) : 0.01
# Ketchapp Summer Sports : 0.01
# Ketchapp Basketball : 0.01
# KINGDOM HEARTS Union χ[Cross] : 0.01
# Just Dance Now : 0.01
# Jupiter Jump : 0.01
# Juju on the Beat : 0.01
# Jelly Blast: New Exciting Match 3 : 0.01
# Javelin Masters 2 : 0.01
# Jam League : 0.01
# It Girl Story - Styling, Fashion & Celebrity Life : 0.01
# Iron Maiden: Legacy of the Beast : 0.01
# Invasion: Modern Empire : 0.01
# Ingress : 0.01
# Icon Pop Song : 0.01
# Hot Wheels: Race Off : 0.01
# Horizon Chase - World Tour : 0.01
# Higher Higher! : 0.01
# He-Man™ Tappers of Grayskull™ : 0.01
# Hand of God - Top Clicker & Tap Games : 0.01
# Guess The Song - New music quiz! : 0.01
# Grumpy Cat's Worst Game Ever : 0.01
# Green the Planet : 0.01
# Good Knight Story : 0.01
# Gods Of Rome : 0.01
# Glowing Snake King - Anaconda Diep War Battle Game : 0.01
# Ghostbusters™: Slime City : 0.01
# Geometry Dash World : 0.01
# Gear.Club - True Racing : 0.01
# Game of Dice : 0.01
# Galaxy Reavers-Space Strategy game(RTS) : 0.01
# Fun Run Arena - Online Multiplayer Running Game : 0.01
# Frozen Frenzy Mania: Challenging Match 3 Games : 0.01
# Football Heroes PRO 2016 : 0.01
# Flow Free: Hexes : 0.01
# Flick Quarterback 17 : 0.01
# Fish Mania™ : 0.01
# Fireboy and Watergirl: Online in the Forest Temple - Multiplayer Running and Adventure Game : 0.01
# Fight List : 0.01
# Fernanfloo : 0.01
# Fear the Walking Dead: Dead Run–Tactical Runner : 0.01
# Fast Motorcycle Driver : 0.01
# Farming Simulator 14 : 0.01
# Faily Brakes : 0.01
# Epic Jackpot Slots: Slot Machines & Bonus Games : 0.01
# Endless Sky : 0.01
# Endless Frontier - Idle RPG with Tactical PVP : 0.01
# Dream City: Metropolis : 0.01
# DragonVale World : 0.01
# Dragon Land : 0.01
# Down The Mountain : 0.01
# Doomsday Clicker : 0.01
# Donut Dazzle : 0.01
# Donald's Empire : 0.01
# Does not Commute : 0.01
# Digimon Heroes! : 0.01
# Diamond Quest! : 0.01
# Design This Castle : 0.01
# Descendants : 0.01
# Dashy Crashy : 0.01
# DUAL! : 0.01
# DRAGON BALL Z DOKKAN BATTLE : 0.01
# Cut the Rope: Time Travel Free : 0.01
# Crazy Cake Swap : 0.01
# Craft your games! - Createrria 2 : 0.01
# Craft Royale: Clash of Pixels : 0.01
# Cops N Robbers (Jail Break) - Survival Mini Game : 0.01
# Cookie Clickers 2 : 0.01
# Cookie Cats - a singing puzzle adventure : 0.01
# Combo Critters : 0.01
# Clockmaker – Mystery Match3 Puzzle : 0.01
# Christmas Sweeper 3 : 0.01
# Card Wars Kingdom - Adventure Time : 0.01
# Can You Dab? : 0.01
# COOKING MAMA Let's Cook！ : 0.01
# Build Away! - Idle City Game : 0.01
# Buffalo Slots - Royal Casino Fun Slot Machines! : 0.01
# Bubble Island 2 - Pop Bubble Shooter : 0.01
# Brain Dots - Draw and solve! Brain Training Game : 0.01
# Bottle Flip! : 0.01
# Bold Moves : 0.01
# Blocky Football : 0.01
# Bits of Sweets : 0.01
# Big Win Football 2016 : 0.01
# Big Bang Racing : 0.01
# Beach Buggy Racing : 0.01
# BattleHand : 0.01
# Battle Copters : 0.01
# Battle Camp HD - Collect & Evolve Your Monsters : 0.01
# Basketball Clicker : 0.01
# Basket Fall - Basketball Dunking Sim : 0.01
# Ball King : 0.01
# Bakery Story 2 : 0.01
# Bakery Blitz: Cooking Game : 0.01
# Baby Care & Dress Up - Love & Have Fun with Babies : 0.01
# BLEACH Brave Souls : 0.01
# Auralux: Constellations : 0.01
# Athletics 2: Summer Sports - Free : 0.01
# Athlete Shave Salon Games : 0.01
# Asphalt Xtreme: Offroad Rally Racing : 0.01
# Amateur Surgeon 4 : 0.01
# Alpha Omega : 0.01
# 50 50 - The Addictive Slicing Game : 0.01
# 1+2=3 : 0.01
# 鏡の中のプリンセス Love Palace : 0.0
# 蒼の彼方のフォーリズム‐ETERNAL SKY- : 0.0
# 花札Online : 0.0
# 脱出ゲーム　Night Room : 0.0
# 脱出ゲーム　In My Heart : 0.0
# 脱出ゲーム　Cottage : 0.0
# 脱出ゲーム Toilet : 0.0
# 脱出ゲーム Oden : 0.0
# 脱出ゲーム KOTATSU : 0.0
# 脱出ゲーム KA-MA-KU-RA : 0.0
# 爆笑アプリ！人気無料ゲーム kimazui gacha : 0.0
# 無料ゲーム HANABI ON LINE 花火（ハナビ）パズル : 0.0
# 机でGOLF : 0.0
# 日曜劇難99.9 : 0.0
# 感動アプリ！無料ゲーム Japanese Gacha : 0.0
# 少年勇者团 (Combo Warrior)-日系Q萌即时战斗消除RPG手游 : 0.0
# 大富豪 Online : 0.0
# 上司と秘密の2LDK　Love Happening : 0.0
# 一骑当千OL-万人国战（Legend Of Warrior） : 0.0
# おじクエ - OJISAN QUEST - タップRPG - : 0.0
# ■ Square it! : 0.0
# ⋆Solitaire⋆ : 0.0
# ∞ Infinity Loop : 0.0
# the SOUL of SEVENS【ソウル オブ セブンス】 : 0.0
# striker – dropping balls : 0.0
# splix.io! : 0.0
# real happy majiang-all stars majiang,mahjong : 0.0
# iSlash Heroes : 0.0
# iPaint uPaint : 0.0
# caRRage : 0.0
# a. - Physical Simulation Puzzle Game : 0.0
# Zootopia Crime Files: Hidden Object : 0.0
# Zombies Chasing Me : 0.0
# Zombie Town Story : 0.0
# Zombie Anarchy: Survival Strategy Game : 0.0
# ZenDots 2 - One Dot’s Journey : 0.0
# Zap Zombies : 0.0
# ZAGA : 0.0
# Z Buster : 0.0
# Yurei Ninja : 0.0
# Yummy Birthday - Party Food Maker : 0.0
# YouTurbo : 0.0
# You hate me? わたしのこと きらい？ : 0.0
# You Stupid : 0.0
# Xmas Swipe - Christmas Match 3 Puzzle : 0.0
# Wrassling : 0.0
# Worm.is: The Game : 0.0
# World Spin - Create & Play : 0.0
# World Craft - Epic Dream Island : 0.0
# WordNerd - The picture puzzle game for word nerds : 0.0
# Wonderball - One Touch Endless Ball Arcade Action : 0.0
# Wonder Tactics : 0.0
# Wizard Swipe : 0.0
# Wire de Coins 2 : 0.0
# Wire Bounce : 0.0
# Winterstate : 0.0
# Winter Fugitives 2: Chronicles : 0.0
# Wild City Rush - Urban Jungle Adventure : 0.0
# White Tiles 2 : Piano Master ( Don't Hit The White Tiles 4 ) - Free Music Game : 0.0
# Where's My What? Free : 0.0
# When you clear one,million yen CHANCE!! : 0.0
# What Jump - Free Pop Arcade Game : 0.0
# Werewolf "Nightmare in Prison" : 0.0
# Wedding Planner - Dress Up, Makeup & Cake Design : 0.0
# Wave : 0.0
# Water Bottle Flip Challenge: Flippy Bottle Diving : 0.0
# Water Bottle Flip Challenge : Endless Diving 2K16 : 0.0
# Water Bottle Flip Challenge : 2k16 : 0.0
# Water Bottle Flip Challenge - 2k16 Pro! : 0.0
# Water Bottle Flip Challenge : 0.0
# Water Bottle Flip AK 2016 : 0.0
# Warriors of Glory : 0.0
# Warp Shift : 0.0
# Warlords - Turn Based Strategy : 0.0
# Warcher Defenders : 0.0
# War of Warship:Pacific War : 0.0
# Wappoi Room Escape : 0.0
# Walls & Balls : 0.0
# Wall Switch : 0.0
# Waiit : 0.0
# WIND runner adventure : 0.0
# Virtual Regatta Offshore : 0.0
# Virtual Reality Roller Coaster for Google Cardboard VR : 0.0
# Virtual Reality Moon for Google Cardboard VR : 0.0
# Vintage Slots Las Vegas - Old Slot Machine Games! : 0.0
# Versus Run : 0.0
# Versus - Multiplayer Game (2 players) : 0.0
# Vector 2 : 0.0
# Vault! : 0.0
# Valley of Fear Virtual Reality : 0.0
# VR-Crazy Car Traffic Racing : 0.0
# VR Water Park:Water Stunt & Ride For VirtualGlasse : 0.0
# VR Thrills: Roller Coaster 360 (Google Cardboard) : 0.0
# VR Street Jump for Google Cardboard : 0.0
# VR SNIPER : 0.0
# VR Roller-Coaster : 0.0
# VR Roller Coaster for Google Cardboard : 0.0
# VR Roller Coaster World - Virtual Reality : 0.0
# VR Roller Coaster : 0.0
# VR Horror Maze Walk :Horror Fever For VR Cardboard : 0.0
# VR Haunted House 3D : 0.0
# VR HORROR : 0.0
# VR Flight Simulator for Google Cardboard : 0.0
# VR Crazy Bike Race: Traffic Racing Free : 0.0
# VR Car Driving Simulator for Google Cardboard : 0.0
# VR Ball for Google Cardboard Virtual Reality : 0.0
# Upperland : 0.0
# Uncolored Boy : 0.0
# Ultimate Briefcase : 0.0
# Ulterior : 0.0
# UNCHARTED: Fortune Hunter™ : 0.0
# UDONちゅるん : 0.0
# Twisty Board : 0.0
# Twin Shooter - Invaders : 0.0
# Trump On The Run : 0.0
# Trump Hoverboard Sim - Mannequin Race Challenge : 0.0
# Trump Bounce : 0.0
# Trucker Parking Simulator 2 a Real Monster Truck & Lorry Driving Test : 0.0
# Tropical Wars - Pirate Battles : 0.0
# Tropical Twist : 0.0
# Trolls: Crazy Party Forest! : 0.0
# Troll Face Quest Video Games : 0.0
# Trio : 0.0
# Triennale Game Collection : 0.0
# TraptionBakery : 0.0
# Trapdoors : 0.0
# Train Conductor World : 0.0
# Trailer Truck Parking with Real City Traffic Car Driving Sim : 0.0
# Trail Jump : 0.0
# Tracky Train : 0.0
# Toy Blocks Game for Brain Traning -TSUMIKI- : 0.0
# Tower Knights! : 0.0
# Tower Conquest : 0.0
# Top Tier : 0.0
# Top Model - Next Fashion Star : 0.0
# Tooth Fairy Princess - Magical Adventure : 0.0
# Toon Shooters 2: The Freelancers : 0.0
# TohTum : 0.0
# Toast Girl : 0.0
# Titan Slots™ III : 0.0
# Titan Brawl : 0.0
# Tip Tap Soccer : 0.0
# Tiny Sea Adventure : 0.0
# Tiny Rails : 0.0
# Tiny Bone : 0.0
# Tiny Archers : 0.0
# Tina's Diary: Spring Outing : 0.0
# Tina's Diary - Star Fever : 0.0
# Tidal Rider : 0.0
# Through The Fog! : 0.0
# Thomas & Friends: Race On! : 0.0
# There's no tablecloth I can't pull!! : 0.0
# The Walls : 0.0
# The Pocket Quiz for Pokemon : 0.0
# The Pit : 0.0
# The Krustashians : 0.0
# The Higher Lower Game : 0.0
# The Counter Of Death : 0.0
# The Cooking Game- With Cute iMessage Food Stickers : 0.0
# The Bomb! : 0.0
# The Blacklist: Conspiracy : 0.0
# Tetro Blocks - Beat IQ with Tetrix-style-puzzle. : 0.0
# Tetminos - Classic Puzzle Game : 0.0
# Tesla Tubes: Solve our Logic Games & Brain Puzzles : 0.0
# Terra Monsters 3 : 0.0
# Tentacles - Enter the Mind : 0.0
# Tennis Bits : 0.0
# Teeter – Endless Arcade Balancer : 0.0
# Teen Titans Go Arcade : 0.0
# Target Acquired : 0.0
# Tapping Monsters : 0.0
# Tap the Blocks : 0.0
# Tap Tap Trillionaire : 0.0
# Tap Tap Builder : 0.0
# Tap Quest : Gate Keeper : 0.0
# Tap My Katamari - Endless Cosmic Clicker : 0.0
# Tap Hero : 0.0
# Tap Cats: Idle Warfare : 0.0
# Tangled Up! - Valentine Special : 0.0
# Talented Pets Show : 0.0
# TRUMP'S WALL - Build it Huge : 0.0
# TLMJ, Tout Le Monde Joue : 0.0
# TIME LOCKER - Shooter : 0.0
# TENOSEL+ : 0.0
# TALES OF LINK : 0.0
# Symmetrica - Minimalistic arcade game : 0.0
# Swoopy Space : 0.0
# Switchy Sides : 0.0
# Swiperoo : 0.0
# Sweet Tales: Match 3 Christmas : 0.0
# Sweet Tales : 0.0
# Sweet Princess Makeup Party - Girls Dressup Games : 0.0
# Sweet Princess Beauty Salon : 0.0
# Swap Ball - Endless Arcade Bouncer : 0.0
# Swaggy Ninja : 0.0
# Suрer Toss The Turtle : 0.0
# Survivor: Prologue : 0.0
# Surfingers : 0.0
# Supermodel Star - Rule the Runway : 0.0
# Supermarket Girl - Shopping Fun! : 0.0
# Super Stickman Golf 3 : 0.0
# Super Smash the Office - Endless Destruction! : 0.0
# Super Slime Blitz – Gumball Endless Arcade Climber : 0.0
# Super Phantom Cat - Be a jumping bro. : 0.0
# Super Knock and Run : 0.0
# Super Jabber Jump : 0.0
# Super Fashion Show - Girls Makeup, Dressup Games : 0.0
# Super Duper Punch : 0.0
# Super Candy: Let's Fix it! : 0.0
# Super Adventures World HD : 0.0
# Summer Vacation - Fun at the Beach : 0.0
# Sumikko gurashi-Puzzling Ways : 0.0
# Sugar Slide: The Path Home : 0.0
# Stupid Again : 0.0
# String Rush : 0.0
# Stretch Dungeon : 0.0
# Stress Release Grenade : 0.0
# Street Fighter Puzzle Spirits : 0.0
# Stop! Thief!! : 0.0
# Stop Curry : 0.0
# Stony Road : 0.0
# Stirfry Stunts – We Bare Bears Cooking Game Starring Chef Ice Bear : 0.0
# Stickninja Smash : 0.0
# Stickman Soccer 2016 : 0.0
# Stickman Ice Hockey : 0.0
# Stickman Forest Swing : 0.0
# Stickman Football : 0.0
# Stickman Cubed : 0.0
# Stickman Basketball 2017 : 0.0
# Stickman Base Jumper 2 : 0.0
# Sticklings : 0.0
# Stick Soccer 2 : 0.0
# Steps! - Hardest Action Game Ever! : 0.0
# Steps : 0.0
# Stay in the Line - Free : 0.0
# Star Skater : 0.0
# Star Cheerleader - High School Tryouts : 0.0
# Stage Rush: Imagine Dragons : 0.0
# Sports Hero : 0.0
# Spoon Pet Collector : 0.0
# Splish Splash Pong : 0.0
# Splat Wars : 0.0
# Splashy Cats: Endless Zigzag Arcade Water Game : 0.0
# Splash Pop : 0.0
# Splash Cars : 0.0
# Splash : 0.0
# Spirit Rush : 0.0
# Spiral Tower : 0.0
# Spiral Splatter : 0.0
# Spinny Phone : 0.0
# Spinning Rings : 0.0
# Spike Run : 0.0
# Spider Solitaire ∙ : 0.0
# Spellbinders : 0.0
# Sparkwave : 0.0
# Spa Birthday Party - Nails, Hair, Dress Up & Cake : 0.0
# Soundtrack Attack - Steven Universe Rhythm Runner : 0.0
# Sophia - My Little Sis : 0.0
# Solitaire ▪ : 0.0
# Solitaire ∘ : 0.0
# Solitaire One : 0.0
# Soda World - Your Soda Inc : 0.0
# Soda Coin Party: Free Casino Pusher : 0.0
# Soccer Stadium Sports Car & Bus Parking Simulator 3D Driving Sim : 0.0
# Soccer Puzzle for Brain Training -SoccerStrike- : 0.0
# Soccer Hit : 0.0
# Soccer Cup Championship 2016 : 0.0
# Snowboarding The Fourth Phase : 0.0
# Snow Roll : 0.0
# Sniper: Traffic Hunter : 0.0
# Snakebird : 0.0
# Snake splix : 0.0
# Snail Bob 2 : 0.0
# Smurfs Epic Run - Fun Platform Adventure : 0.0
# Smelly Baby - Farty Party : 0.0
# Smash Slots : 0.0
# Smash Fu - Endless Arcade Smasher : 0.0
# Smart Matches ~ Puzzles with Matchsticks : 0.0
# Slots: Get Rich Slot Machines Casino Slot Games : 0.0
# Slots: Fast Fortune Slot Machines & Fun Slot Games : 0.0
# Slots of Vegas - Play Free Casino slot machines! : 0.0
# Slots Real Las Vegas - Free Casino Slot Machine Games - Bet, Spin and Win Jackpot & Bonus : 0.0
# Slots Discovery : 0.0
# Sloomy : 0.0
# Slip Away : 0.0
# Slingshot Rush : 0.0
# Slide the Shakes : 0.0
# Skylanders™ Creator : 0.0
# Skylanders SuperChargers : 0.0
# Sky Pillar : 0.0
# Sky Hoppers : 0.0
# Sky Chasers : 0.0
# Sky Charms : 0.0
# Skippy Box : 0.0
# SkillTwins Football Game : 0.0
# Ski Resort Parking Sim Ice Road Snow Plow Trucker : 0.0
# Sir Match-a-Lot – Match 3 Puzzle Game : 0.0
# Simulator Run Real Hologram : 0.0
# Simple Reversi Online : 0.0
# Silly Sausage: Doggy Dessert : 0.0
# Shoutrageous! - The Addictive Game of Lists : 0.0
# Shopping Mall Car Parking Simulator a Real Driving Racing Game : 0.0
# Shogi : 0.0
# Shark Boom - Challenge Friends with your Pet : 0.0
# Shadow Bug Rush : 0.0
# Seashine : 0.0
# Science Girl - School Lab Super Star : 0.0
# School Lunch Food! : 0.0
# Save The Line : 0.0
# Save Dan : 0.0
# Sausage Legend - Fighting Game : 0.0
# Santa Kids Hair Salon - Christmas Makeover Games : 0.0
# Samurai Ninja Puzzle ONIMARU : 0.0
# Sacred Legends : 0.0
# SUDOKU -The puzzle game that makes your brain younger!- : 0.0
# SPEED:3D Racing : 0.0
# SLOTS: TRUMP vs. HILLARY CLINTON Free Slot Games : 0.0
# SLAAAASH ! -Cut and Smash ! refreshing Puzzle- : 0.0
# SBK16 - Official Mobile Game : 0.0
# S, - Puzzle Game With Create Level Feature : 0.0
# Running Man Challenge - Game : 0.0
# Run Sackboy! Run! : 0.0
# Run From Trump : 0.0
# Rubin.io : 0.0
# Rope Racers - Fun Multiplayer Racing Game : 0.0
# Rooms of Doom : 0.0
# Room Escape [SECRET CODE 2] : 0.0
# Room Escape Game - Santa's Room : 0.0
# Room Escape Game - Pictures Room Esacpe : 0.0
# Roof Jumping 3 Stunt Driver Parking Simulator an Extreme Real Car Racing Game : 0.0
# Rolly Worms : 0.0
# Roller Coaster VR : 0.0
# Roller Coaster Simulator - Draw and Simulate! : 0.0
# Rogue Ninja : 0.0
# Rockstar Girls - Crazy Concert Day : 0.0
# Rocket Cars : 0.0
# Rock The School - Class Clown : 0.0
# Robocide : 0.0
# Robbery Bob 2: Double Trouble : 0.0
# Road to be King : 0.0
# Rival Stars College Football : 0.0
# Risky Rooms : 0.0
# Rising Warriors: War Games - The New Order : 0.0
# Rise! : 0.0
# Rio 2016 Olympic Games : 0.0
# Rings. : 0.0
# Ridiculous Parking Simulator a Real Crazy Multi Car Driving Racing Game : 0.0
# Ridge Runner : 0.0
# Riddle Stones - Cross Numbers : 0.0
# Rhinbo - Endless Runner Game : 0.0
# Reversi REAL - Multiplayer Board game : 0.0
# Respeck on my Name : 0.0
# Refreshing ! Brain training fit : 0.0
# Redungeon : 0.0
# RedStory - Little Red Riding Hood : 0.0
# Red Bull Air Race 2 : 0.0
# Red Ball UP! - Bounce Dash & Dodge Spikes : 0.0
# Really Bad Chess : 0.0
# Real Cake Maker 3D - Bake, Design & Decorate : 0.0
# Real Bouncy Basketball : 0.0
# ReRunners: Race for the World : 0.0
# Re:Monster : 0.0
# Rayman Classic : 0.0
# Rapala Fishing - Daily Catch : 0.0
# Race Driving School Car Racing Driver License Test : 0.0
# Raccoon Pizza Rush : 0.0
# ROCKY™ : 0.0
# ROAD -escape game- : 0.0
# REVERSI ZERO - free classic game : 0.0
# RAMBOAT - Game of Shoot and Dash, Run and Jump ! : 0.0
# RAID HQ : 0.0
# RAD Boarding : 0.0
# Quizduell : 0.0
# Quiz Tales : 0.0
# QB Hero : 0.0
# Puzzlepops! Trick or Treat : 0.0
# Puzzle it to 10 : 0.0
# Puzzle Monster Quest - New MultiPlayer : 0.0
# Puzzle Game for Brain Training!! PITATTO!! : 0.0
# Puzzle Game for Brain Training -KITINTO- : 0.0
# Push the Arrow : 0.0
# Pursuit of Light2 : 0.0
# Puppy Love - My Dream Pet : 0.0
# Puppy Life - Secret Pet Party : 0.0
# Psych : 0.0
# Protect The Planet : 0.0
# Prop Hunt : 0.0
# Pro Series Drag Racing : 0.0
# Princess Swimming & Spa - Girls Beauty Game FREE : 0.0
# Princess Salon: Frozen Party : 0.0
# Princess Pet Palace: Royal Puppy - Pet Care, Play & Dress Up : 0.0
# Princess Pet Palace: Royal Pony - Pet Care, Play & Dress Up : 0.0
# Princess Libby: Frozen Party : 0.0
# Princess Libby's Perfect Beach Day : 0.0
# Princess Fairy Rush - Pony Rainbow Adventure : 0.0
# Princess Face Paint - Girls Makeup, Dressup and Makeover Games : 0.0
# Primal Legends : 0.0
# Pretty Ballerina - Ballet Dreams : 0.0
# Pozzle Blocks : 0.0
# PopSwish Basketball by Andrew Wiggins : 0.0
# Pop The Circle! : 0.0
# Pop Girls - High School Band : 0.0
# Pony Princess Academy - Dress Up, Style, Feed & Care for Ponies Game : 0.0
# Polyforge : 0.0
# Political Knockout PKO Presidential Fight : 0.0
# Police Sniper Prison Guard : 0.0
# Police Chase Race : 0.0
# Poker - Texas Holdem HD Poker : 0.0
# Pokelog for PokemonGO : 0.0
# PokeWhere - Live Radar Map for Pokemon GO : 0.0
# Pocket Troops : 0.0
# Pocket Rush : 0.0
# Plummet Dash : 0.0
# Please,Dad. I wanna live.　おとうさん、おねがい。わたし生きたいよ。 : 0.0
# Play-Doh TOUCH - Shape, Scan, Explore : 0.0
# Play Basketball Hoops 2017 - Real slam dunks game : 0.0
# Plantera - Idle Farm Clicker : 0.0
# Plane Flying Parking Sim a Real Airplane Driving Test Run Simulator Racing Games : 0.0
# Pixelgrams: Pixel Puzzles : 0.0
# Pixel Strike-Sniper zombies shooting games : 0.0
# Pixel Disc Golf 2 : 0.0
# Pixduel™ : 0.0
# Pirates Kids Room Escape : 0.0
# Pink Pong : 0.0
# Pinball Breaker Forever : 0.0
# Pinata Hunter 3 : 0.0
# Pigu : 0.0
# Piggy Show : 0.0
# Piggy Boom : 0.0
# Phoenix II : 0.0
# Pharaoh's Party: Coin Pusher : 0.0
# Peter Panic : 0.0
# Perfect Square! : 0.0
# Perfect Fit : 0.0
# Pelé: Soccer Legend : 0.0
# Pathfinder Adventures : 0.0
# Path of War : 0.0
# Pastry Picnic : 0.0
# Particular : 0.0
# Parallels : 0.0
# Paper Girl - Morning Madness Adventures : 0.0
# Pantheon Warfare: The Chaos of Knights : 0.0
# Panic Drop : 0.0
# Paddle Panic : 0.0
# PICTLOGICA FINAL FANTASY : 0.0
# PAC-MAN Pop : 0.0
# PAC-MAN Bounce - Puzzle Adventure : 0.0
# Outfolded : 0.0
# Our dark lord-Sasuyu 2-TAP RPG : 0.0
# Otaku quizzes from manga, and anime--Slice HEROES! : 0.0
# Osteya: Adventures : 0.0
# Osmo Words : 0.0
# Osmo Tangram : 0.0
# Osmo Numbers : 0.0
# Osmo Newton : 0.0
# Osmo Monster : 0.0
# Osmo Masterpiece : 0.0
# Osmo Coding Awbie : 0.0
# Order's Up : 0.0
# Oops You Died : 0.0
# Ookujira - Giant Whale Rampage : 0.0
# Online Reversi World : 0.0
# One Tap Tennis : 0.0
# One More Spin! - Free Vegas Casino Slots : 0.0
# One More Jump : 0.0
# One More Dash : 0.0
# One More Bounce : 0.0
# Oil Hunt : 0.0
# Offroad 4x4 Truck Trials Parking Simulator a Real Car Stunt Driving Racing Sim : 0.0
# Offroad 4x4 Truck Trials Parking Simulator 2 a Real Stunt Car Driving Racing Sim : 0.0
# Offline IV Calc for Pokemon GO : 0.0
# Offline Auto IV Calc for Pokemon GO : 0.0
# OctoPie - a Game Shakers App : 0.0
# Ocean Overlord - Global War : 0.0
# Ocean Clash: A naval game with honor and loyalty : 0.0
# Obstacle Course Extreme Car Parking Simulator : 0.0
# OUTDODGE : 0.0
# ON-SEN - escape game - : 0.0
# OK K.O.! Lakewood Plaza Turbo : 0.0
# NumberQ : 0.0
# Nukleus : 0.0
# Nope Quiz : 0.0
# No Limit Racer : 0.0
# Nitro Heads : 0.0
# Ninja UP! : 0.0
# Ninja Dude vs Zombies - endless tap 'n' slash zombie arcade game : 0.0
# NinjAwesome : 0.0
# New baseball board app BasePinBall : 0.0
# New York City Car Taxi and Bus Parking Simulator : 0.0
# New Star Cricket : 0.0
# NeverKnew - Game night is back : 0.0
# Never Gone : 0.0
# Neon Horizon : 0.0
# NeoWars : 0.0
# Nekosan : 0.0
# Nasty Goats – a Game Shakers App : 0.0
# NHL SuperCard 2K17 : 0.0
# Myth Kingdom:Wrath of Gauss : 0.0
# Mystic Castle - the Simplest & Best RPG and Adventure Game : 0.0
# My Teacher - School Classroom Play & Learn : 0.0
# My Sweet Farm : 0.0
# My Rockstar Girls - Party Rock Band : 0.0
# My Newborn Kitty - Fluffy Care : 0.0
# My Newborn Baby - Mommy & Baby Care : 0.0
# My New Baby Story - Makeup Spa & Dressup Games : 0.0
# My NBA 2K17 : 0.0
# My Majesty : 0.0
# My First Crush - High School Love : 0.0
# My Boo Town - Create your own Village of Boos : 0.0
# Mushroom Wars 2 : 0.0
# MultiCraft -- Survival Craft Build Sandbox Game : 0.0
# Multi Level Car Parking 6 Shopping Mall Garage Lot : 0.0
# Multi Level Car Parking 5 a Real Airport Driving Test Simulator : 0.0
# Multi Level 4 Car Parking Simulator a Real Driving Test Run Racing Games : 0.0
# Muhammad Ali: Puzzle King : 0.0
# Mucho Party : 0.0
# Mr. Crab 2 : 0.0
# Move the Match - Matchstick Puzzles for Free : 0.0
# Motor World: Bike Factory : 0.0
# Moonvale 2: Puzzle Adventure : 0.0
# Monster Zombie Plague War - Virtual Reality (VR) : 0.0
# Monster Tail : 0.0
# Monster Strike : 0.0
# Monster Raid™ : 0.0
# Monster Mania : 0.0
# Monster Busters: Link Flash : 0.0
# Monster & Commander : 0.0
# Monkey Swingers : 0.0
# Money Multiplier : 0.0
# Mixels Rush - Use Mixes, Maxes and Murps to Outrun the Nixels : 0.0
# Minescape : 0.0
# MineSweeper　マインスイーパ無料 : 0.0
# Mimpi : 0.0
# Mikey Jumps : 0.0
# Midnight Calling: Jeronimo : 0.0
# Microtrip : 0.0
# Micromon : 0.0
# Microgolf Masters : 0.0
# Micro Machines : 0.0
# Medal Masters : Call of destiny : 0.0
# Maze Walk VR - Virtual Reality Game Puzzle Apps : 0.0
# Maximum Car : 0.0
# Matchsticks ~ Free Puzzle Game with Matches : 0.0
# Match 3 Puzzle - Mr.Rockets - : 0.0
# Masky : 0.0
# Marry Me - Perfect Wedding Day! : 0.0
# Mannequin Challenge : 0.0
# Make-Up Touch 2 - Kids Games & Girls Dressup Game : 0.0
# Majiang Mahjong（单机+川麻+二人+武汉+国标） : 0.0
# Maim Street : 0.0
# Mahjöng : 0.0
# Mahjong Panda : 0.0
# Magnets! : 0.0
# Magic Nightfall : 0.0
# Magic Mansion : 0.0
# Magic Legion - Age of Heroes : 0.0
# Mafia Mystery : 0.0
# Mafia III: Rivals : 0.0
# Mad City Gangs: Nice City : 0.0
# Mad City Crime : 0.0
# MOOMIN -Welcome to Moominvalley- : 0.0
# MOBA Legends : 0.0
# METAL SLUG ATTACK : 0.0
# METAL SAGA -Ark in the wild land- : 0.0
# MARVEL Tsum Tsum : 0.0
# Lumo Deliveries : 0.0
# Love Engine : 0.0
# Lost in Harmony : 0.0
# Lost Socks: Naughty Brothers : 0.0
# Lords & Castles - Medieval War Strategy MMO Games : 0.0
# Looty Dungeon : 0.0
# Loop Taxi : 0.0
# Loop Mania : 0.0
# LongStory: Choose your own dating game : 0.0
# Lonely One : 0.0
# Logic Traces : 0.0
# Lock The Block : 0.0
# Little Broken Robots : 0.0
# Line Defense : 0.0
# Linda Brown: Interactive Story : 0.0
# Limo Driving School a Valet Driver License Test Parking Simulator : 0.0
# Limite Limite : 0.0
# Light On : 0.0
# Lewandowski: Football Star : 0.0
# Levels - Addictive Puzzle Game : 0.0
# Leveled! : 0.0
# Level With Me : 0.0
# Legendary - Game of Heroes : 0.0
# Learn 2 Fly : 0.0
# Lastronaut : 0.0
# Las Vegas Valet Limo and Sports Car Parking : 0.0
# Lane Racer : 0.0
# Landix.io Online : 0.0
# LOST MAZE : 0.0
# LONEWOLF : 0.0
# LINE RUSH ! : 0.0
# LINE PokoPoko : 0.0
# LINE FIGHTERS : 0.0
# LINE Bubble 2 : 0.0
# LINE BROWN FARM : 0.0
# LEGO® Ninjago: Skybound : 0.0
# LEGO® NEXO KNIGHTS™ : MERLOK 2.0 : 0.0
# LEGO® DC Super Heroes Mighty Micros : 0.0
# LEGO® City My City 2 : 0.0
# LEAD ZAQ Battle Version : 0.0
# Kuro no Sekai - It's a Darkness World : 0.0
# Kungfu Street-Ultimate Fight : 0.0
# Kubo: A Samurai Quest ™ - Match, Collect, Battle! : 0.0
# Kubik : 0.0
# Krosmaster Arena : 0.0
# Knots - The Ultimate Brain Challenge : 0.0
# Knights of Pen & Paper 2 : 0.0
# Knights Fight: Medieval Arena : 0.0
# King Rabbit : 0.0
# Kids Play Club - Fun Games & Activities : 0.0
# Kids Movie Night - Popcorn & Soda : 0.0
# Kickerinho World : 0.0
# Kick Hero : 0.0
# Ketchapp Tennis : 0.0
# Ketchapp Soccer : 0.0
# Kerflux : 0.0
# Keepy Ducky : 0.0
# KSI Unleashed : 0.0
# KOMRAD : 0.0
# Just Trap : 0.0
# Just Rolling : 0.0
# Just Dance Controller : 0.0
# Jurassic Virtual Reality (VR) : 0.0
# Junk Yard Trucker Parking Simulator a Real Monster Truck Extreme Car Driving Test Racing Sim : 0.0
# Jumpy Tree : 0.0
# Jumps - Jumping on Pillars Game : 0.0
# Jumping Balls! : 0.0
# Jump on piano stack : 0.0
# Jump Buddies : 0.0
# Juju on that Beat Challenge : 0.0
# Juju On That Beat  - Dance Challenge Game : 0.0
# Juggernaut Champions : 0.0
# Jrump : 0.0
# Joan Mad Run : 0.0
# Jigsaw Puzzle for Brain Training -PITATOY- : 0.0
# Jewel Mania: Valentine's : 0.0
# Jet Plane Fighter Pilot Flying Simulator Real War Combat Fighting Games : 0.0
# Jet Car Stunts 2 : 0.0
# Jelly Squares Free : 0.0
# Javelin Masters 3 : 0.0
# It's a Space Thing : 0.0
# Is-it Love ? Ryan (Visual Novel) : 0.0
# Iron Mission- classic arcade shoot'em up : 0.0
# Iron Commander : 0.0
# Ire - Blood Memory : 0.0
# Into the Dim : 0.0
# Into Mirror : 0.0
# Inner Circle : 0.0
# Infinite Skater : 0.0
# Indoor soccer – football Dream league journey : 0.0
# Independence Day Resurgence: Battle Heroes : 0.0
# InMind VR (Cardboard) : 0.0
# Impulse GP - Super Bike Racing : 0.0
# ImpossibleGO! - You can't clear : 0.0
# Impossible Goal 3D : 0.0
# Immortal Legends - TD : 0.0
# Idle Armies : 0.0
# Icy Ropes : 0.0
# Ice Road Trucker Parking Simulator 2 a Real Monster Truck Car Park Racing Game : 0.0
# Ice Princess - Royal Wedding Day : 0.0
# Ice Cream Truck Girl - Frozen Sweets Maker : 0.0
# Ice Age: Arctic Blast : 0.0
# Icarus - A Star's Journey : 0.0
# IQ200 - If you can clear all stage : 0.0
# I, Viking : 0.0
# I Have A Pen : 0.0
# Human Juggling Cup : 0.0
# Hugo Troll Race 2. : 0.0
# Hugo Flower Flush : 0.0
# Hovercrash : 0.0
# Hoverboard Simulator - Night Drive : 0.0
# Hoverboard Simulator - Endless Hover Board Race : 0.0
# Hoverboard Simulator : 0.0
# Hoverboard Rush Racing Simulator -Hover Board Game : 0.0
# House of Terror VR : 0.0
# Hot Pot Master : 0.0
# Hop Swap : 0.0
# Hop Shot : 0.0
# Hop Rush : 0.0
# Hood Jump – The Best Platform Game in the Streets : 0.0
# Home Run X 3D - Baseball Batting Game : 0.0
# Hollywood Rush : 0.0
# Hockey Stars : 0.0
# Hockey Clicker : 0.0
# Hillarymon Go : 0.0
# High School Crush - My First Love : 0.0
# High Risers : 0.0
# High Dive : 0.0
# High 5 Vegas - Hit Slots Casino : 0.0
# Hidden my game by mom - escape room : 0.0
# Hidden Pictures by Highlights Magazine : 0.0
# Hey Duggee: The Tinsel Badge : 0.0
# Hexy! : 0.0
# Hexavoid : 0.0
# Hex Crush! : 0.0
# Hero Simulator: clicker game and idle adventure : 0.0
# Helmet Virtual Reality 3D Joke : 0.0
# Hello, Mr.Rich : 0.0
# Hello Kitty Lunchbox – Food Maker : 0.0
# Hell Run - Scary Road : 0.0
# Heavy Metal Tennis Training : 0.0
# Head Soccer France 2016 : 0.0
# Haywire Hospital : 0.0
# Haunted Rooms: Escape VR Game for Google Cardboard : 0.0
# Hat Trick Shots : 0.0
# Harvest Land : 0.0
# Happy Oink : 0.0
# Handbrake Valet : 0.0
# Hammer Time! : 0.0
# Hammer Bomb - Creepy Dungeon Mazes! : 0.0
# Halloween Face Paint Spa - Kids Makeup Salon Games : 0.0
# Halfpipe Hero - Retro Arcade Skateboarding : 0.0
# Hairy Face Salon - Messy Shave Makeover : 0.0
# Hair Fashion™ - Girls Makeup, Dressup and Makeover Games : 0.0
# Hackers - Join the Cyberwar! : 0.0
# HOLE. : 0.0
# HIT - Heroes of Incredible Tales : 0.0
# GyroSphere Trials : 0.0
# Gweep Gwop : 0.0
# Gun Master 3: Zombie Slayer : 0.0
# Gun Fu: Stickman 2 : 0.0
# Green the Planet 2 : 0.0
# Gravity Trump : 0.0
# Gravity Switch : 0.0
# Gravity Square! : 0.0
# Gravity Island - Shiro's Adventure : 0.0
# Grandpa, what the fone? : 0.0
# Goosebumps Night of Scares : 0.0
# Golf Island : 0.0
# Golden Lotus Slots : 0.0
# GodFinger 2 : 0.0
# Goal Kick - free penalty shootout soccer game : 0.0
# Goal Finger : 0.0
# Go!Go!Cat! : 0.0
# Go! No. MM! Even amateur exit the record? : 0.0
# Go Up : 0.0
# Go Surf - The Endless Wave Runner : 0.0
# Go Pug Go : 0.0
# Go Karts - VR : 0.0
# Glory of Generals 2 : 0.0
# Glob Trotters - Endless Arcade Blobber : 0.0
# Glitch Fixers - The Powerpuff Girls : 0.0
# Give It Up! 2 : 0.0
# Girls PJ Party - Dress Up, Spa & Fun : 0.0
# Giant Turnip Game: A Voyage Of Vegetable Extraction! : 0.0
# Geometry Lock : 0.0
# Gems Story : 0.0
# Geki Yaba Runner : 0.0
# Gear Miner : 0.0
# Gate Keepers : 0.0
# Gas Station Car Parking Simulator a Real Road Racing Park Game : 0.0
# Garfield: My BIG FAT Diet : 0.0
# Gang City : 0.0
# Game Switch : 0.0
# Galaga Wars : 0.0
# Fusion Pictures - A Multiplayer Game with 4 Hidden Pics Object & 1 Word Puzzle : 0.0
# Fruit Pop! Puzzles in Paradise - Fruit Pop Sequel : 0.0
# Frozen Free Fall: Icy Shot : 0.0
# Free Gameplay Video, Walkthroughs, News for Pokémon GO : 0.0
# Free Fur All – We Bare Bears Minigame Collection : 0.0
# Frantic Ball : 0.0
# Frantic Architect : 0.0
# Forsaken World Mobile MMORPG : 0.0
# Forest Rescue 2: Friends United Match 3 Puzzle : 0.0
# Forest Heroes Story : 0.0
# Football Heroes PRO 2017 - featuring NFL Players : 0.0
# Focus! - Can You Tell Them Apart? : 0.0
# Flying Police Car Driving Simulator Free: Criminal Craft Chase : 0.0
# Flying Car Simulator 3D: Stunt Bus : 0.0
# Flying Car Driving Simulator Free: Extreme Muscle Car - Airplane Flight Pilot : 0.0
# Flutter: Starlight : 0.0
# Flower Girl - Crazy Wedding Day : 0.0
# Flip That Bottle : 0.0
# Flip King : 0.0
# Flip Heroes : 0.0
# Flip Football - Soccer Manager Strategy Card Game : 0.0
# Flip : 0.0
# Flick Soccer 17 : 0.0
# Flick Rugby 16 : 0.0
# Flick Golf Extreme : 0.0
# Flick Field Goal 17 : 0.0
# Flappy Hoopers: The Shooting Basketball Players : 0.0
# Flappy Golf 2 : 0.0
# Flappy Bird : original version ! : 0.0
# Flail Rider : 0.0
# Fix It Girls - House Makeover : 0.0
# Five Finger Fury : 0.0
# Fits - Block Puzzle King : 0.0
# Fitness Girl - Dance and Play at the Gym : 0.0
# Fit In The Hole : 0.0
# Fishing Break : 0.0
# Fish Fist : 0.0
# Fired Up : 0.0
# Finger Hero: Avoid Obstacles : 0.0
# Final Kick VR - Virtual Reality free soccer game for Google Cardboard : 0.0
# Fill - one-line puzzle game : 0.0
# Fiete Sports : 0.0
# Fieldrunners Attack! : 0.0
# Fetty Wap: Nitro Nation Stories : 0.0
# Feed’em Burger : 0.0
# Fatal : 0.0
# Fast Food Rampage : 0.0
# Fantasy Football Coach : 0.0
# Fantastic Beasts™: Cases : 0.0
# Fancy Makeup Shop - Brush & Blush : 0.0
# Fancy Cats : 0.0
# Fancy Cakes - Endless Tasty Puzzle : 0.0
# Fallen London : 0.0
# Fairytale Fiasco - Sleeping Spell Rescue : 0.0
# Fairytale Fiasco - Royal Rescue : 0.0
# Fairy Princess Fashion Design : 0.0
# Fairy Land Rescue - Save the Magic Village : 0.0
# Faily Rider : 0.0
# Face Up - The Selfie Game : 0.0
# Face Paint Party Salon - Girls Makeup & Kids Games : 0.0
# Face Paint Party - Kids Coloring Fun : 0.0
# FaZes - Run & Jump : 0.0
# FURBY CONNECT World : 0.0
# FALLMAN – Trampoline Action : 0.0
# Eyes Cube : 0.0
# Extreme Trucks Simulator : 0.0
# Extreme Heavy Trucker Parking Simulator : 0.0
# Extreme Forklifting 2 : 0.0
# Exodus : 0.0
# Exit Zone : 0.0
# EvilBane: Rise of Ravens : 0.0
# Evil Zombie Graveyard Apocalypse Shooting VR Games : 0.0
# Evil Dead: Endless Nightmare : 0.0
# Evel Knievel : 0.0
# European War 5: Empire : 0.0
# Escape the Sweet Shop Series : 0.0
# Escape the Ice Cream Parlor : 0.0
# Escape the Cake Café : 0.0
# Escape from the wedding hall. : 0.0
# Escape from the pit latrine. : 0.0
# Escape from the music room in the school. : 0.0
# Escape from the living room during the Obon holiday. : 0.0
# Escape from the grandma house in the countryside. : 0.0
# Escape from the frigid Igloo. : 0.0
# Escape from the beach house of everlasting summer. : 0.0
# Escape from the ICU room. : 0.0
# Escape from the Bears of the student council room. : 0.0
# Escape from the Art Gallery. : 0.0
# Escape from many tutoring school of test. : 0.0
# Escape a Halloween Candy Shop : 0.0
# Escape a Crepe House : 0.0
# Escape With Words : 0.0
# Escape Game: illumination : 0.0
# Escape Game: Traps : 0.0
# Escape Game: Signs : 0.0
# Escape Game: Relief : 0.0
# Escape Game: Red room : 0.0
# Escape Game: Fountain : 0.0
# Escape Game: Forgotten : 0.0
# Escape Game: Christmas Eve : 0.0
# Escape Game Darkness LittleRedHood : 0.0
# Escape Game : Escape from Okinawa : 0.0
# Escape Game  Escape from Lost Memory : 0.0
# Escape Alice House2 : 0.0
# Escalate : 0.0
# Epic Orchestra : 0.0
# Epic Flail : 0.0
# Epic Battle Simulator : 0.0
# Endless Ducker : 0.0
# Emoji Blitz : 0.0
# Emily’s Polar Adventure : 0.0
# Emergency Surgery Simulator - Doctor Game FOR FREE : 0.0
# Eden: The Game - Build Your Village! : 0.0
# EatMe.io: Hungry Fish Attack! : 0.0
# Eat Game : 0.0
# Earth Defender S - Trillion Battle Game : 0.0
# Earn to Die 2 Lite : 0.0
# Ear Age Diagnosis : 0.0
# EXORUN : 0.0
# EVERYTOWN : 0.0
# ENYO : 0.0
# EA SPORTS™ FIFA 17 Companion : 0.0
# Dustoff Heli Rescue 2 : 0.0
# Dunkers : 0.0
# Dungeon Witcher : 0.0
# Dungeon Monsters RPG : 0.0
# Dulp : 0.0
# Duel Master - Best Duelist : 0.0
# Ducky Fuzz - Chain Reaction : 0.0
# Duck Roll : 0.0
# Droppy Balls! : 0.0
# Dropple : 0.0
# DropEraser : 0.0
# Drop Out! : 0.0
# Driving Zone : 0.0
# Driving Evolution Parking Sim Real Car Driver Test : 0.0
# Drive Ahead! Sports : 0.0
# Drifty Chase : 0.0
# Dream Diary - My Life, My Adventure! : 0.0
# Dream Defense : 0.0
# Dragon Heroes: Shooter RPG : 0.0
# Douchebag Beach Club : 0.0
# Double Juggle : 0.0
# Dot Empires : 0.0
# Doodle Jump Easter Special : 0.0
# Donuts Maker Salon : 0.0
# Don't Grind : 0.0
# Don't Be Squared : 0.0
# Dominocity : 0.0
# Doggy Box : 0.0
# Dofus Pogo : 0.0
# Disney Magical Dice : 0.0
# Disney Jigsaw Puzzles! : 0.0
# Disco Dave : 0.0
# Diner Dynasty : 0.0
# Dictator: Emergence : 0.0
# Dictator 2 : 0.0
# Diced - A Simple Puzzle Dice Game : 0.0
# Dice Mania - Play Free Online Classic Board Game with Friends : 0.0
# Dice Crush : 0.0
# Diamond Story: Jewelry Quest : 0.0
# Devil Lord: I shouldn't say that...half of world : 0.0
# Der IQ Test - Intelligenztest (Deutsch) : 0.0
# Dentist Mania: Doctor X Crazy Clinic : 0.0
# Demolition Derby Virtual Reality (VR) Racing : 0.0
# Demi Lovato - Zombarazzie Adventure : 0.0
# DelusionCreatureGacha : 0.0
# Delicious - Emily’s Message in a Bottle : 0.0
# Defenders 2: Tower Defense battle of the frontiers : 0.0
# Defend the Planet : 0.0
# Deck Heroes: Legacy : 0.0
# Deamon's Dungeon : 0.0
# Dead Zone: Zombie Crisis : 0.0
# Dead Center : 0.0
# Dawnbringer : 0.0
# Dawn of Gods : 0.0
# Dashy the Cat : 0.0
# Dashy Box : 0.0
# Dash Up 2 : 0.0
# Dash Masters : 0.0
# Dash Heroes : 0.0
# Dark Sword : 0.0
# Danger Dodgers : 0.0
# Dancing with the Stars: The Official Game : 0.0
# Daddy's Little Helper - Messy Home Adventure : 0.0
# DOFUS Touch : 0.0
# DANDY DUNGEON Legend of Brave Yamada : 0.0
# Cyber Reversi : 0.0
# Cut the Rope HD™ : 0.0
# Curvulate : 0.0
# Cubway : 0.0
# Cubicle. : 0.0
# Cubed Rally World : 0.0
# CubeMator - Craft, Build and Explore the World : 0.0
# Cube Skip : 0.0
# Cube Roll : 0.0
# Crystal Rush! Color Shoot Arcade Game : 0.0
# Crossy Maze : 0.0
# Crooked Path: Infinity Run : 0.0
# Crooked Path : 0.0
# Critter Academy : 0.0
# Cristiano Ronaldo: Kick'n'Run : 0.0
# Crime City Real Action Simulator Theft kill shooting- sniper game : 0.0
# Crazy Truck! : 0.0
# Crazy Nursery - Newborn Baby Doctor Care : 0.0
# Crazy Maze - Traffic Puzzle : 0.0
# Crazy Love Story - Wedding Dreams : 0.0
# Crazy Freekick : 0.0
# Crazy Eye Clinic - Doctor X Adventures : 0.0
# Crazy Clown Chase : 0.0
# Crazy Circle : 0.0
# Crane Game Toreba! : 0.0
# Cosmic Challenge: Best online space racing game : 0.0
# Cops N Robbers (Jail Break 2) - Survival Mini Game : 0.0
# Cops - On Patrol : 0.0
# Cops & Robbers! : 0.0
# Cool Jigsaw Puzzles : 0.0
# Cooking Mama Let's Cook Puzzle : 0.0
# Cookie Run: OvenBreak : 0.0
# Conduct THIS! : 0.0
# Combo Quest 2 : 0.0
# Colorpede : 0.0
# Color Dotz : 0.0
# Color Bots : 0.0
# Color 6: Blitz : 0.0
# Color 6 : 0.0
# Cola Bottle Flip Challenge : 0.0
# Coin Party: Carnival Pusher : 0.0
# Coin Dozer: Haunted : 0.0
# Coin Dozer: Casino : 0.0
# Coco Pony - My Dream Pet : 0.0
# Coach Bus Simulator : 0.0
# Classic Poker - Texas Holdem : 0.0
# Clashy Colors : 0.0
# Clash of Richers 3 （城市富翁3） : 0.0
# Clash of Queens: Dragons Rise : 0.0
# City Police Car Driver Simulator – Drive Cops Auto : 0.0
# City Car Driving : 0.0
# Circuroid : 0.0
# Circlify : 0.0
# Circles : 0.0
# Circle Swing : 0.0
# Circle Boom2 - Wheel Puzzle Game : 0.0
# Circle Boom : 0.0
# Circle Affinity : 0.0
# Chunky Tanks : 0.0
# Chrome Death : 0.0
# Christmas Sweeper 2 : 0.0
# Christmas Swap 3 -Match toy & candy to countdown : 0.0
# Christmas Stories: The Gift of the Magi : 0.0
# Choppa : 0.0
# Chocolate Candy Party - Fudge Madness : 0.0
# Chick Go & Climb : 0.0
# Chef's Quest : 0.0
# Chef Siblings - Island Restaurant : 0.0
# Chaos Chronicle : 0.0
# Chaos Centurions : 0.0
# Championship Manager 17 : 0.0
# Catch the Bus : 0.0
# Catch Rate : 0.0
# CatHotel - Care for cute cats : 0.0
# Cat-A-Pult: Endless stacking of 8-bit kittens : 0.0
# Cat Monsters : 0.0
# Casino X - Free Slot Machines, Poker, Blackjack : 0.0
# Casino Girl-お金稼ぎ美少女育成ゲーム- : 0.0
# Cartoon Wars 3 : 0.0
# Car Factory Parking Simulator a Real Garage Repair Shop Racing Game : 0.0
# Candy's Vacation - Beach Hotel : 0.0
# Candy's Carnival : 0.0
# Candy Party: Coin Carnival Dozer : 0.0
# Candy Makeup - Sweet Salon Game for Girls : 0.0
# Cake Break : 0.0
# Cafe Story - Play Cooking & Farming Game : 0.0
# CLUE Bingo: Valentine’s Day : 0.0
# Buzzy Bubbles : 0.0
# Bushido Bear : 0.0
# Bus Driving Taxi Parking Simulator Real Extreme Car Racing Sim : 0.0
# Burnout City : 0.0
# Burgers & Shakes - Fast Food Maker : 0.0
# Burger – The Game : 0.0
# Burger Jump : 0.0
# Bumper Jump : 0.0
# Bullet Hell Monday : 0.0
# Bullet Boy : 0.0
# Buildy Blocks : 0.0
# Building World - Create Your Castle & City : 0.0
# Buddyman Run － keep running! : 0.0
# Buddy Toss : 0.0
# Bubble Shoot Pet : 0.0
# Bubble Buggie : 0.0
# Brutal Street : 0.0
# Britney Spears: American Dream : 0.0
# Brio - Don’t Fall! : 0.0
# Bridge Rider : 0.0
# Bridge Construction Simulator 3D a Real City Building Physics Sim : 0.0
# Bridge : 0.0
# Brick Splits : 0.0
# Brick Shot : 0.0
# Brick Rage - Not for the Weak Heart : 0.0
# Break Liner : 0.0
# Brake or Break : 0.0
# BrainTraining!!GASHAAAAAAN!! : 0.0
# Brain15 − 脳トレ 無料パズル − : 0.0
# Brain Block -脳トレ分解パズル- : 0.0
# Boyfriend Plus - Brett Jeff and Kai : 0.0
# Bouncy Tower : 0.0
# Bouncy Kingdom : 0.0
# Bouncing Ball 2 : 0.0
# Bounce Balls - Strike Game : 0.0
# Boom Boom Soccer : 0.0
# Boom Boom Football : 0.0
# Book - room escape game - : 0.0
# Boo - The World's Cutest Dog Game! : 0.0
# Bonecrusher: Free Awesome Endless Skull & Bone Game : 0.0
# Blocky Soccer - Endless Arcade Runner : 0.0
# Blocky Racer - Endless Arcade Racing : 0.0
# Blocky Hockey - Arcade Ice Runner : 0.0
# Blocky Basketball - Endless Arcade Dunker : 0.0
# BlazBlue RR - the Real Action Game : 0.0
# Blair's Fashion Boutique - School Style : 0.0
# Blade Sliders : 0.0
# Billion Hunter - Casual Monster Clicker RPG : 0.0
# Billiards9 : 0.0
# Billiards8 (8 Ball & Mission) : 0.0
# Bike Unchained : 0.0
# Bike Traffic Rider an Extreme Real Endless Road Racer Racing Game : 0.0
# Bike Race Level 100 : 0.0
# Beyond 14 : 0.0
# Bernie Sandwiches - Run For The White House : 0.0
# Beneath The Lighthouse : 0.0
# Bella's Pizza Place - Italian Food Maker : 0.0
# Being SalMan: The Official Game : 0.0
# Behind You!! : 0.0
# Beat the Boss 4 : 0.0
# Beat Racer : 0.0
# Beast Poker : 0.0
# Bear Pop - Bubble Shooter Game : 0.0
# Battlestar Galactica: Squadrons™ : 0.0
# Battleplans - #1 Battle Strategy & Defense Game : 0.0
# Battleborn® Tap : 0.0
# Battle Golf : 0.0
# Battle Bears Overclock FPS Epic Multiplayer Shooting Games : 0.0
# Batman v Superman: Who Will Win : 0.0
# Basketball Free Throw : 0.0
# Ball Tower : 0.0
# Ball Maze! : 0.0
# Ball Escape! : 0.0
# Back To Square One : 0.0
# Babysitter Madness - Help the Nanny : 0.0
# Babysitter Craziness - Fun Kids Game : 0.0
# Baby Twins - Terrible Two : 0.0
# Baby Kim - Care, Play & Dress Up : 0.0
# Baby Full House - Care, Play and Have Fun : 0.0
# Baby Food Fair - Make, Eat, Play - Have Fun! : 0.0
# Baby Bottle Challenge - Water Bottle Flip : 0.0
# Baby Boss - Care, Dress Up and Play : 0.0
# Baby Airlines - Airport Adventures : 0.0
# BLOCK(ブロック) -ぼくの箱庭【3D】- : 0.0
# BFB Champions 2.0 ~Football Club Manager~ : 0.0
# BARRIER X : 0.0
# Axe in Face 2 : 0.0
# Auto Warriors - Tactical Car Combat : 0.0
# Auto IV Calc for PokemonGO : 0.0
# Aussie Rules Hero - Footy Goal Kicking Game : 0.0
# Asterix and Friends : 0.0
# Army of Heroes : 0.0
# Arma Mobile Ops : 0.0
# Arcane Online - Fantasy MMORPG : 0.0
# Ao Oni2 : 0.0
# Angry Birds Action! : 0.0
# Amusement Park Tour 2: Fun Xmas : 0.0
# Amusement Park Tour : 0.0
# Amusement Park Fair Ground Circus Trucker Parking Simulator : 0.0
# Alternative Girls : 0.0
# Alpaca World HD+ : 0.0
# Alliance: Air War - Airplane Flight Simulator Game : 0.0
# Alliance Wars: World Domination : 0.0
# All is Lost : 0.0
# All Star Quarterback 17 - Football Lifestyle Sim : 0.0
# All Limpy Run! : 0.0
# Age of Heroes: Conquest : 0.0
# Again - room escape game : 0.0
# Aeronaut : 0.0
# Adventure Cube : 0.0
# Adventure Company : 0.0
# Advent Calendar 2017 - The Game : 0.0
# A.P.E.X : 0.0
# 8-BIT WATERSLIDE : 0.0
# 5E Spell Book : 0.0
# 4x4 Dirt Track Trials Forest Driving Parking Sim : 0.0
# 4 Images 1 Mot : 0.0
# 4 Bilder 1 Wort : 0.0
# 3D Maze Level 100 : 0.0
# 3D Dubai Parking Simulator Drive Real Extreme Super Sports Car : 0.0
# 3D Car Racing Simulator Real Drag Race Rivals Road Chase Driving Games : 0.0
# 360 Degree : 0.0
# 12オーディンズ - 王道RPG : 0.0
# 1000m Zombie Escape! : 0.0
# 100 PICS Coloring - free color in book game app : 0.0
# 1-Bit Rogue: A dungeon crawler RPG! : 0.0
# *Solitaire* : 0.0
# ! OH Fantastic Free Kick + Kick Wall Challenge : 0.0

# %%
print('===android-Games===')
display_table(app_percent_of_user_counts(android_free, 1, 'GAME', 3, 0))
# Out:
# ===android-Games===
# Clash of Clans : 7.62
# Subway Surfers : 4.71
# Clash Royale : 3.93
# Candy Crush Saga : 3.81
# My Talking Tom : 2.53
# 8 Ball Pool : 2.41
# Shadow Fight 2 : 1.86
# Pou : 1.78
# Pokémon GO : 1.77
# Yes day : 1.71
# My Talking Angela : 1.68
# Dream League Soccer 2018 : 1.68
# Hill Climb Racing : 1.51
# Asphalt 8: Airborne : 1.42
# Mobile Legends: Bang Bang : 1.4
# Temple Run 2 : 1.38
# Piano Tiles 2™ : 1.38
# Sniper 3D Gun Shooter: Free Shooting Games - FPS : 1.3
# Trivia Crack : 1.09
# Geometry Dash Lite : 1.05
# Candy Crush Soda Saga : 1.05
# Hungry Shark Evolution : 1.03
# Garena Free Fire : 0.94
# Angry Birds Classic : 0.94
# Score! Hero : 0.92
# Traffic Racer : 0.91
# slither.io : 0.89
# Fruit Ninja® : 0.86
# Zombie Tsunami : 0.84
# Dr. Driving : 0.84
# Gangstar Vegas - mafia game : 0.82
# Jetpack Joyride : 0.79
# Pixel Gun 3D: Survival shooter & Battle Royale : 0.76
# Crossy Road : 0.72
# Smash Hit : 0.7
# Gardenscapes : 0.7
# Plants vs. Zombies FREE : 0.69
# Temple Run : 0.68
# DEER HUNTER CLASSIC : 0.67
# Angry Birds 2 : 0.66
# Angry Birds Go! : 0.65
# Agar.io : 0.65
# Sonic Dash : 0.64
# PUBG MOBILE : 0.63
# Banana Kong : 0.59
# Need for Speed™ No Limits : 0.57
# Cooking Fever : 0.54
# Homescapes : 0.53
# War Robots : 0.52
# Vector : 0.52
# MORTAL KOMBAT X : 0.52
# Lords Mobile: Battle of the Empires - Strategy RPG : 0.52
# Modern Combat 5: eSports FPS : 0.49
# Hill Climb Racing 2 : 0.47
# Talking Tom Gold Run : 0.46
# Bike Race Free - Top Motorcycle Racing Games : 0.44
# Angry Birds Rio : 0.44
# MARVEL Contest of Champions : 0.42
# Injustice: Gods Among Us : 0.41
# Last Day on Earth: Survival : 0.39
# Extreme Car Driving Simulator : 0.38
# GUNSHIP BATTLE: Helicopter 3D : 0.37
# Fishdom : 0.37
# Swamp Attack : 0.36
# Cut the Rope FULL FREE : 0.36
# Summoners War : 0.35
# Zynga Poker – Texas Holdem : 0.34
# Toy Blast : 0.32
# Words With Friends Classic : 0.29
# UNO ™ & Friends : 0.29
# Glow Hockey : 0.29
# FRONTLINE COMMANDO: D-DAY : 0.29
# Bubble Witch 3 Saga : 0.29
# Geometry Dash Meltdown : 0.27
# Call of Duty®: Heroes : 0.27
# CATS: Crash Arena Turbo Stars : 0.26
# Bowmasters : 0.26
# Helix Jump : 0.25
# DEAD TARGET: FPS Zombie Apocalypse Survival Games : 0.25
# Best Fiends - Free Puzzle Game : 0.25
# Special Forces Group 2 : 0.24
# Roll the Ball® - slide puzzle : 0.24
# Red Ball 4 : 0.24
# Critical Ops : 0.24
# Toon Blast : 0.23
# RULES OF SURVIVAL : 0.23
# FRONTLINE COMMANDO : 0.23
# Earn to Die 2 : 0.23
# DINO HUNTER: DEADLY SHORES : 0.23
# Chess Free : 0.23
# ► MultiCraft ― Free Miner! 👍 : 0.22
# Flow Free : 0.22
# Candy Crush Jelly Saga : 0.22
# Super Mario Run : 0.21
# Hungry Shark World : 0.21
# Guns of Boom - Online Shooter : 0.21
# Angry Birds Star Wars : 0.21
# Skater Boy : 0.2
# Ant Smasher by Best Cool & Fun Games : 0.2
# Rolling Sky : 0.19
# Pixel Art: Color by Number Game : 0.19
# Live Hold’em Pro Poker - Free Casino Games : 0.19
# Harry Potter: Hogwarts Mystery : 0.19
# Granny : 0.19
# Draw Something Classic : 0.19
# Blossom Blast Saga : 0.19
# Five Nights at Freddy's 3 Demo : 0.18
# Doodle Jump : 0.18
# Zombie Catchers : 0.17
# Kick the Buddy : 0.17
# KIM KARDASHIAN: HOLLYWOOD : 0.17
# Family Guy The Quest for Stuff : 0.17
# The Sims™ FreePlay : 0.16
# DEER HUNTER 2018 : 0.16
# Block Strike : 0.16
# Block Craft 3D: Building Simulator Games For Free : 0.16
# Bike Racing 3D : 0.16
# World Series of Poker – WSOP Free Texas Holdem : 0.15
# Five Nights at Freddy's 4 Demo : 0.15
# Stick War: Legacy : 0.14
# Perfect Piano : 0.14
# Modern Strike Online : 0.14
# Lep's World 2 🍀🍀 : 0.14
# Crisis Action: 2018 NO.1 FPS : 0.14
# Choices: Stories You Play : 0.14
# BMX Boy : 0.14
# Angry Birds Friends : 0.14
# Piano Free - Keyboard with Magic Tiles Music Games : 0.13
# Lep's World 3 🍀🍀🍀 : 0.13
# Just Dance Now : 0.13
# Geometry Dash World : 0.13
# FINAL FANTASY BRAVE EXVIUS : 0.13
# Bus Rush: Subway Edition : 0.13
# Bomber Friends : 0.13
# Words With Friends – Play Free : 0.12
# Racing Moto : 0.12
# PAC-MAN : 0.12
# Lep's World 🍀 : 0.12
# Cover Fire: offline shooting games for free : 0.12
# Rider : 0.11
# DRAGON BALL Z DOKKAN BATTLE : 0.11
# Bullet Force : 0.11
# Beach Buggy Blitz : 0.11
# Robbery Bob : 0.1
# Magic Tiles 3 : 0.1
# Kill Shot Bravo: Sniper FPS : 0.1
# Hustle Castle: Fantasy Kingdom : 0.1
# ETERNITY WARRIORS 2 : 0.1
# DH Texas Poker - Texas Hold'em : 0.1
# Asphalt Xtreme: Rally Racing : 0.1
# The Walking Dead: Road to Survival : 0.09
# Partymasters - Fun Idle Game : 0.09
# My Boy! Free - GBA Emulator : 0.09
# Mini Golf King - Multiplayer Game : 0.09
# Major Mayhem : 0.09
# Injustice 2 : 0.09
# Galaxy Attack: Alien Shooter : 0.09
# Fernanfloo : 0.09
# Dan the Man: Action Platformer : 0.09
# Cytus : 0.09
# Cash, Inc. Money Clicker Game & Business Adventure : 0.09
# BLACKJACK! : 0.09
# Anger of stick 5 : zombie : 0.09
# Alto's Adventure : 0.09
# Stupid Zombies : 0.08
# Solitaire TriPeaks : 0.08
# Rope Hero: Vice Town : 0.08
# Knife Hit : 0.08
# Final Fantasy XV: A New Empire : 0.08
# Eyes - The Scary Horror Game Adventure : 0.08
# Dr. Parking 4 : 0.08
# Deck Heroes: Legacy : 0.08
# The Maze Runner : 0.07
# Texas HoldEm Poker Deluxe : 0.07
# THE KING OF FIGHTERS-A 2012(F) : 0.07
# Solitaire! : 0.07
# Snake VS Block : 0.07
# SAMURAI vs ZOMBIES DEFENSE : 0.07
# Real City Car Driver : 0.07
# NinJump : 0.07
# Ingress : 0.07
# Grand Gangsters 3D : 0.07
# Dude Perfect 2 : 0.07
# Arena of Valor: 5v5 Arena Game : 0.07
# diep.io : 0.06
# Zombie Hunter: Post Apocalypse Survival Games : 0.06
# Zombie Frontier : 0.06
# Word Search : 0.06
# Rivals at War: Firefight : 0.06
# Nyan Cat: Lost In Space : 0.06
# Love Balls : 0.06
# Heroes Arena : 0.06
# Dragon Hills : 0.06
# Dr. Driving 2 : 0.06
# DRAGON BALL LEGENDS : 0.06
# Cooking Madness - A Chef's Restaurant Games : 0.06
# Checkers : 0.06
# Can Knockdown 3 : 0.06
# Call of Mini™ Dino Hunter : 0.06
# Bike Mayhem Free : 0.06
# Big Fish Casino – Play Slots & Vegas Games : 0.06
# Arrow.io : 0.06
# Toy Truck Rally 3D : 0.05
# Toughest Game Ever 2 : 0.05
# TRANSFORMERS: Forged to Fight : 0.05
# Standoff 2 : 0.05
# Soul Knight : 0.05
# Slot Machines by IGG : 0.05
# Shoot Hunter-Gun Killer : 0.05
# Run Sausage Run! : 0.05
# Real Gangster Crime : 0.05
# Race the Traffic Moto : 0.05
# Quiz: Logo game : 0.05
# NARUTO X BORUTO NINJA VOLTAGE : 0.05
# MARVEL Avengers Academy : 0.05
# Kung Fu Do Fighting : 0.05
# Jurassic World™ Alive : 0.05
# Jewels Legend - Match 3 Puzzle : 0.05
# Hard Time (Prison Sim) : 0.05
# Fidget Spinner : 0.05
# DEER HUNTER RELOADED : 0.05
# iGun Pro -The Original Gun App : 0.04
# Wordscapes : 0.04
# Word Link : 0.04
# Word Crossy - A crossword game : 0.04
# War and Order : 0.04
# Truck Driver Cargo : 0.04
# Solitaire : 0.04
# Shooting King : 0.04
# Rush : 0.04
# Rope'n'Fly 4 : 0.04
# Racing in Car 2 : 0.04
# Power Rangers: Legacy Wars : 0.04
# Miami crime simulator : 0.04
# Merge Dragons! : 0.04
# Love Nikki-Dress UP Queen : 0.04
# I Know Stuff : 0.04
# I Am Innocent : 0.04
# Hopeless Land: Fight for Survival : 0.04
# Heart of Vegas™ Slots – Free Slot Casino Games : 0.04
# Governor of Poker 2 - OFFLINE POKER GAME : 0.04
# Geometry Dash SubZero : 0.04
# GUN ZOMBIE : 0.04
# Experiment Z - Zombie : 0.04
# Draw a Stickman: EPIC Free : 0.04
# Draw a Stickman: EPIC 2 Free : 0.04
# Call of Mini™ Zombies 2 : 0.04
# CONTRACT KILLER: ZOMBIES (NR) : 0.04
# CKZ ORIGINS : 0.04
# Bike Rivals : 0.04
# Big Hunter : 0.04
# Battlefield™ Companion : 0.04
# BEYBLADE BURST app : 0.04
# 1LINE – One Line with One Touch : 0.04
# Train Racing Games 3D 2 Player : 0.03
# Texas Holdem & Omaha Poker: Pokerist : 0.03
# Tank Stars : 0.03
# TEKKEN™ : 0.03
# Sweet Fruit Candy : 0.03
# Squadron - Bullet Hell Shooter : 0.03
# Space Shooter : Galaxy Attack : 0.03
# Scratch Logo Quiz. Challenging brain puzzle : 0.03
# San Andreas Crime Stories : 0.03
# STARDOM: THE A-LIST : 0.03
# SCRABBLE : 0.03
# Rope'n'Fly 3 - Dusk Till Dawn : 0.03
# Rento - Dice Board Game Online : 0.03
# Power Rangers Dino Charge : 0.03
# Pineapple Pen : 0.03
# Peggle Blast : 0.03
# Motorbike Driving Simulator 3D : 0.03
# Miraculous Ladybug & Cat Noir - The Official Game : 0.03
# Miami Crime Vice Town : 0.03
# Metal Soldiers 2 : 0.03
# Marble Woka Woka 2018 - Bubble Shooter Match 3 : 0.03
# Mafia City : 0.03
# Lineage 2: Revolution : 0.03
# Iron Blade : 0.03
# HAWK – Force of an Arcade Shooter. Shoot 'em up : 0.03
# Grim Soul: Dark Fantasy Survival : 0.03
# Golden HoYeah Slots - Real Casino Slots : 0.03
# Gems or jewels ? : 0.03
# Flip the Gun - Simulator Game : 0.03
# Dragonplay™ Poker Texas Holdem : 0.03
# Does not Commute : 0.03
# Defender : 0.03
# Creative Destruction : 0.03
# Cops N Robbers - FPS Mini Game : 0.03
# Cartoon Wars: Blade : 0.03
# Bubble Shooter : 0.03
# Bingo by IGG: Top Bingo+Slots! : 0.03
# Bingo Party - Free Bingo Games : 0.03
# Baseball Boy! : 0.03
# Avatar Musik : 0.03
# nds4droid : 0.02
# Z Champions : 0.02
# WithstandZ - Zombie Survival! : 0.02
# Wheelie Challenge : 0.02
# Texas Holdem Poker Pro : 0.02
# Texas Holdem Poker : 0.02
# TAMAGO Monsters Returns : 0.02
# Survival: Prison Escape : 0.02
# Survival Run with Bear Grylls : 0.02
# Super Dancer : 0.02
# Street Skater 3D : 0.02
# Strange Hero: Future Battle : 0.02
# StirFry Stunts - We Bare Bears : 0.02
# Stack Jump : 0.02
# Sonic the Hedgehog™ Classic : 0.02
# Sniper Killer Shooter : 0.02
# SHADOWGUN LEGENDS : 0.02
# Rolly Vortex : 0.02
# Red Hands – 2-Player Games : 0.02
# Power Pop Bubbles : 0.02
# Navy Gunner Shoot War 3D : 0.02
# Moto Rider : 0.02
# Mini Motor Racing WRT : 0.02
# Mini DAYZ: Zombie Survival : 0.02
# Last Shelter: Survival : 0.02
# Identity V : 0.02
# IV Go（get IV for Pokemon） : 0.02
# Hole.io : 0.02
# Hello Stars : 0.02
# Hambo : 0.02
# Guns of Glory : 0.02
# Gun Strike Shoot : 0.02
# Gun Builder ELITE : 0.02
# Gear.Club - True Racing : 0.02
# Game of Thrones: Conquest™ : 0.02
# Fruit Block - Puzzle Legend : 0.02
# Four In A Line Free : 0.02
# Fast like a Fox : 0.02
# Evil Apples: A Dirty Card Game : 0.02
# Drag'n'Boom : 0.02
# Dr. Chess : 0.02
# Disney Heroes: Battle Mode : 0.02
# CrossFire: Legends : 0.02
# Crazy Wheels : 0.02
# Counter Terrorist Attack : 0.02
# Counter Attack - Multiplayer FPS : 0.02
# Color by Number – New Coloring Book : 0.02
# Classic Words Solo : 0.02
# Cheating Tom 3 - Genius School : 0.02
# CONTRACT KILLER: ZOMBIES : 0.02
# Bunny Skater : 0.02
# Block Gun 3D: Ghost Ops : 0.02
# Beauty Idol: Fashion Queen : 0.02
# Battlelands Royale : 0.02
# BLOOD & GLORY: IMMORTALS : 0.02
# Angelo Rules - Crazy day : 0.02
# iSniper 3D Arctic Warfare : 0.01
# Word Search multilingual : 0.01
# WDAMAGE: Car Crash Engine : 0.01
# Voxel - 3D Color by Number & Pixel Coloring Book : 0.01
# Tomb of the Mask : 0.01
# Tiny Archers : 0.01
# The Walking Zombie: Dead City : 0.01
# The Visitor : 0.01
# The Grand Wars: San Andreas : 0.01
# The Cube : 0.01
# TerraGenesis - Space Colony : 0.01
# Super Jabber Jump 3 : 0.01
# Super Jabber Jump : 0.01
# Sudoku Master : 0.01
# Speed Racing Ultimate 2 : 0.01
# Solitaire: Decked Out Ad Free : 0.01
# Snes9x EX+ : 0.01
# Smashy Road: Arena : 0.01
# Sky Streaker - Gumball : 0.01
# Skip-Bo™ Free : 0.01
# Shred! Downhill Mountainbiking : 0.01
# Shoot Strike War Fire : 0.01
# Shadowverse CCG : 0.01
# Rope Hero 3 : 0.01
# RC Monster Truck - Offroad Driving Simulator : 0.01
# Police Car Driver : 0.01
# Paint Hit : 0.01
# Once Upon a Tower : 0.01
# Oggy : 0.01
# Nights at Cube Pizzeria 3D – 2 : 0.01
# New YAHTZEE® With Buddies Dice Game : 0.01
# My OldBoy! Free - GBC Emulator : 0.01
# Mupen64+AE FREE (N64 Emulator) : 0.01
# Motocross Motorbike Simulator Offroad : 0.01
# Motocross Mayhem : 0.01
# Moto Fighter 3D : 0.01
# Mopar Drag N Brag : 0.01
# Might & Magic: Elemental Guardians : 0.01
# Marble - Temple Quest : 0.01
# Mad Skills Motocross : 0.01
# Mad Skills BMX 2 : 0.01
# MMX Hill Dash 2 – Offroad Truck, Car & Bike Racing : 0.01
# MLB TAP SPORTS BASEBALL 2018 : 0.01
# Love Dance : 0.01
# Looper! : 0.01
# L.A. Crime Stories Mad City Crime : 0.01
# Just A Regular Arcade : 0.01
# Jungle Monkey Run : 0.01
# Jewels classic Prince : 0.01
# Horror Hospital : 0.01
# Honkai Impact 3rd : 0.01
# Heroes of Dragon Age : 0.01
# Hero Hunters : 0.01
# Gun Club Armory : 0.01
# Guess The Emoji : 0.01
# Glitch Fixers: Powerpuff Girls : 0.01
# Gangster Town : 0.01
# Fun Texas Hold'em Poker : 0.01
# Fruits Bomb : 0.01
# Fields of Battle : 0.01
# Fatal Raid - No.1 Mobile FPS : 0.01
# Fancy Pants Adventures : 0.01
# Faketalk - Chatbot : 0.01
# Driving Zone : 0.01
# Drift Legends : 0.01
# Draw N Guess Multiplayer : 0.01
# Draw In : 0.01
# Dr. Rocket : 0.01
# Dr. Gomoku : 0.01
# Dino T-Rex : 0.01
# DEER HUNTER CHALLENGE : 0.01
# Cube Z (Pixel Zombies) : 0.01
# Counter Online FPS Game : 0.01
# Cops N Robbers 2 : 0.01
# Cops N Robbers : 0.01
# Commando Adventure Assassin : 0.01
# Color Road : 0.01
# Chicken Invaders 3 : 0.01
# Chapters: Interactive Stories : 0.01
# Casino X - Free Online Slots : 0.01
# Carnivores: Dinosaur Hunter : 0.01
# Car Race by Fun Games For Free : 0.01
# Candy Bomb : 0.01
# Bricks n Balls : 0.01
# Boyaa Poker (En) – Social Texas Hold’em : 0.01
# Bounce Classic : 0.01
# Block Puzzle : 0.01
# Block Gun 3D: Call of Destiny : 0.01
# Blackjack : 0.01
# Bike Race - Bike Blast Rush : 0.01
# BF Frontline City : 0.01
# Au Mobile: Audition Chính Hiệu : 0.01
# Asylum Night Shift - Five Nights Survival : 0.01
# Assault Line CS Online Fps Go : 0.01
# Angry Birds Space HD : 0.01
# ARK: Survival Evolved : 0.01
# AE Coin Mania : Arcade Fun : 0.01
# AE Bingo: Offline Bingo Games : 0.01
# AE 3D MOTOR :Racing Games Free : 0.01
# 4 in a row : 0.01
# Аim Training for CS : 0.0
# ¡Ay Metro! : 0.0
# that's lit : 0.0
# kick the buddy : 0.0
# Zombie War Z : Hero Survival Rules : 0.0
# Zombie Sniper 3D III : 0.0
# Zombie Hunter King : 0.0
# Zombie Death Shooter : 0.0
# Zlax.io Zombs Luv Ax : 0.0
# ZOMBIE RIPPER : 0.0
# Your rank CS:GO : 0.0
# X-WOLF : 0.0
# World of Warriors: Duel : 0.0
# Word Hunt : 0.0
# Woody Puzzle : 0.0
# Woodman Deluxe : 0.0
# Winter Wonderland : 0.0
# Will it Crush? : 0.0
# Who am I? (Biblical) : 0.0
# What's Your CS:GO rank? : 0.0
# What Am I? - Brain Teasers : 0.0
# Water Surfer Racing In Moto : 0.0
# Virtual Dice EX : 0.0
# Vikings: an Archer's Journey : 0.0
# Vikings Stickman Axe Fighting : 0.0
# VR AG Racing for Cardboard : 0.0
# VIP Backgammon Free : Play Backgammon Online : 0.0
# V for Voodoo : 0.0
# Undead Assault : 0.0
# Ultimate Quiz for CS:GO - Skins | Cases | Players : 0.0
# Ultimate Fighter Z : 0.0
# Ultimate DC Challenge : 0.0
# Ultimate BlackJack 3D FREE : 0.0
# U-48 Submarine Commander Free : 0.0
# Two Nights at jumpscare : 0.0
# True Skateboarding Ride Skateboard Game Freestyle : 0.0
# Trovami se ci riesci : 0.0
# Traffic Sniper Counter Attack : 0.0
# Toy Attack : 0.0
# Tokyo Ghoul: Dark War : 0.0
# Them Bombs: co-op board game play with 2-4 friends : 0.0
# The Walking Dead: Our World : 0.0
# The Visitor: Ep.2 - Sleepover Slaughter : 0.0
# The Visitor: Ep.1 - Kitty Cat Carnage : 0.0
# The Vikings : 0.0
# The Q - Live Trivia Game Network : 0.0
# The Great Wobo Escape Ep. 1 : 0.0
# The Grand Way : 0.0
# The Gang Sniper V. Pocket Edition. : 0.0
# The Fish Master! : 0.0
# Thai Sic Bo : 0.0
# Texas Hold’em Poker + | Social : 0.0
# Texas HoldEm Poker Deluxe (BR) : 0.0
# Texas Hold'em Poker : 0.0
# Teen Patti by BL Games : 0.0
# Tamago egg : 0.0
# Sword of Chaos - Lame du Chaos : 0.0
# SuperBikers 2 : 0.0
# Super ball DZ : 0.0
# Super Jim Jump - pixel 3d : 0.0
# Super Hero M Craft Run : 0.0
# Super Dancer VN : 0.0
# Super DK vs Kong Brother Advanced Free Classic : 0.0
# Super Car F. Mod for MCPE : 0.0
# Stickman and Axe : 0.0
# Stickman Warriors Heroes 2 : 0.0
# Stick 'Em Up 2 Starter Edition : 0.0
# Stack It AR : 0.0
# Sports Car Driving Simulator 2018 : 0.0
# Space X: Sky Wars of Air Force : 0.0
# Sonic CD Classic : 0.0
# Soccer Clubs Logo Quiz : 0.0
# Snowboard Racing Free Fun Game : 0.0
# SnowMobile Parking Adventure : 0.0
# Sniper Traning for CS GO : 0.0
# Sniper Gun Shot 3D: Impossible Missions : 0.0
# Slendrina X : 0.0
# Sin City Hero : Crime Simulator of Vegas : 0.0
# Sin City Crime Simulator V - Gangster : 0.0
# Simple x3DS Emulator - BETA : 0.0
# Sid Story : 0.0
# Sic Bo Rave : 0.0
# Sic Bo Online! Free Casino : 0.0
# Sic Bo (Tai Xiu) - Multiplayer Casino : 0.0
# Shooter Sniper CS - FPS Games : 0.0
# Shoot`Em Down: Shooting game : 0.0
# Shoot! DX - lights for FREE : 0.0
# Shoot Bubble - Fruit Splash : 0.0
# Sermon on Proverbs CH Spurgeon : 0.0
# SecondSecret ‐「恋を読む」BLノベルゲーム‐ : 0.0
# Santa Panda Bubble Christmas : 0.0
# San Andreas: Gang Crime V : 0.0
# San Andreas City : Auto Theft Car gangster : 0.0
# Saiyan Z: Super SSJ Ultimate Combat : 0.0
# Runner 3d like : 0.0
# Route Z : 0.0
# Roulette Advisor LITE : 0.0
# Rope Superhero Unlimited : 0.0
# Rope Hero Return of a Legend : 0.0
# Rolling G Sky : 0.0
# Rock n Roll Music Quiz Game : 0.0
# Rock N' Cash Casino Slots -Free Vegas Slot Games : 0.0
# Robot Fighting Games™ - Real Boxing Champions 3D : 0.0
# Robocar X Ray : 0.0
# RetroArch : 0.0
# Rescue Robots Survival Games : 0.0
# Reload: The Z-Team : 0.0
# Real Casino:Slot,Keno,BJ,Poker : 0.0
# Rage Z: Multiplayer Zombie FPS Online Shooter : 0.0
# Rage Fight of Streets - Beat Em Up Game : 0.0
# Radial-G : Infinity : 0.0
# Racing CX : 0.0
# Race Manager FP : 0.0
# RUN JUMP RUN-fun games for free : 0.0
# RIDE ZERO : 0.0
# RC City Police Heavy Traffic Racer : 0.0
# R-EU-READY : 0.0
# Quiz TRUE or FALSE : 0.0
# Quiz DC : 0.0
# Quiz CS:GO players : 0.0
# Q*bert: Rebooted : 0.0
# Puzzle for CS:GO : 0.0
# Puppy Shooting an AK-47: Platformer Zombie Game : 0.0
# Punch em : 0.0
# Project Grand Auto Town Sandbox Beta : 0.0
# PokerStars Play: Free Texas Holdem Poker Game : 0.0
# Poker Pro.Fr : 0.0
# Poker Live! 3D Texas Hold'em : 0.0
# PlayTexas Hold'em Poker Free : 0.0
# Pixel Z Gunner 3D - Battle Survival Fps : 0.0
# Palavras la cq : 0.0
# Pacific Navy Fighter C.E. (AS) : 0.0
# PRO MX MOTOCROSS 2 : 0.0
# PLANK! : 0.0
# Out of Bounds BH Demo : 0.0
# One Night at Golden Freddy's : 0.0
# Offroad drive : 4x4 driving game : 0.0
# Offroad Outlaws : 0.0
# Nights at Slender Pizzeria 3D : 0.0
# Nights at Cube Pizzeria 3D – 4 : 0.0
# Nedir Bu ? : 0.0
# NDS Emulator - For Android 6 : 0.0
# Multicraft Miner Exploration : 0.0
# Monster Ride Pro : 0.0
# Modern Sniper Strike: Best Commando Action 2k18 : 0.0
# Modern Counter Terrorist FPS Shoot : 0.0
# Modern Counter Terror Attack – Shooting Game : 0.0
# Modern Counter Global Strike 3D V2 : 0.0
# Modern Counter Global Strike 3D : 0.0
# Modern Action Commando 3D : 0.0
# Mobile CS:GO : 0.0
# Mirror’s Edge™ Companion : 0.0
# Millionaire : Who want to be? : 0.0
# Mental Hospital:EB 2 Lite : 0.0
# MegaNDS (NDS Emulator) : 0.0
# MazeMilitia Classic Multiplayer Shooting Game : 0.0
# Master of Eternity(MOE) : 0.0
# Mass Effect: Andromeda APEX HQ : 0.0
# Map Callouts for CS:GO : 0.0
# Magnum 3.0 Gun Custom SImulator : 0.0
# Magic Tiles - TWICE Edition (K-Pop) : 0.0
# Magic Tiles - Blackpink Edition (K-Pop) : 0.0
# Mad Day - Truck Distance Game : 0.0
# Mad Dash Fo' Cash : 0.0
# M3-X5-X6-M-İ3-İ8 RACİNG 2018 : 0.0
# M-acceleration 3D Car Racing : 0.0
# Lust in Terror Manor - The Truth Unveiled | Otome : 0.0
# Ludo Dz : 0.0
# Let's Poke The Egg : 0.0
# Law of Creation: A Playable Manga : 0.0
# LA Stories 4 New Order Sandbox 2018 : 0.0
# L.A. Crime Stories 2 Mad City Crime : 0.0
# Korean Dungeon: K-Word 1000 : 0.0
# Knife&Axe Throwing : 0.0
# Justice League Action Run : 0.0
# Jungle book-The Great Escape : 0.0
# Jungle Marble Blast : 0.0
# Jewels Star: OZ adventure : 0.0
# J-Stars Victory VS Guide : 0.0
# J Balvin Piano Tiles : 0.0
# Invasion: Defend EU : 0.0
# Ice Crush 2018 - A new Puzzle Matching Adventure : 0.0
# How well do you know me? : 0.0
# Hotel Insanity : 0.0
# Hide N Seek : Mini Game : 0.0
# Hero Fighter X : 0.0
# Helix : 0.0
# Heirs & Graces : 0.0
# HANGAME Casino - Baccarat & Texas Hold'em : 0.0
# Gunship Modern Combat 3D : 0.0
# Guns Royale - Multiplayer Blocky Battle Royale : 0.0
# Gun Shoot War Q : 0.0
# Guess the song of J Balvin : 0.0
# Guess the Class 🔥 AQW : 0.0
# Grim Tales: The Wishes CE : 0.0
# Grand Stickman Cover V : 0.0
# Grand Bat Superhero Flying Assault Rescue Mission : 0.0
# Girls' Frontline : 0.0
# Ghost Snap AR Horror Survival : 0.0
# Ghost Hunting camera : 0.0
# Get 'Em : 0.0
# Gate Of Death Ep: 1 : 0.0
# Gangster City Auto Theft : 0.0
# Gang Wars of San Andreas : 0.0
# GALAK-Z: Variant Mobile : 0.0
# G-Switch 3 : 0.0
# G-Switch 2 : 0.0
# G-Switch : 0.0
# Frontline Terrorist Battle Shoot: Free FPS Shooter : 0.0
# Freecell CY : 0.0
# Free Poker Games : Downtown Casino - Texas Holdem : 0.0
# Free DS Emulator : 0.0
# Four In A Line : 0.0
# Forgotten Hill: Surgery : 0.0
# Forgotten Hill: Puppeteer : 0.0
# Forgotten Hill: Fall : 0.0
# Forgotten Hill Mementoes : 0.0
# Fo Fo Fish : 0.0
# Flippy Axe : Flip The Knife & Axe Simulator : 0.0
# Flat Pack : 0.0
# Five Nights at Pizzeria : 0.0
# Five Nights at Neighbor House : 0.0
# Five Nights at Flappy's : 0.0
# Fate/Grand Order (English) : 0.0
# Fast Racing Car Simulator : 0.0
# Fast Motorcycle Driver 2016 : 0.0
# Farm Fruit Pop: Party Time : 0.0
# FaFaFa™ Gold Casino: Free slot machines : 0.0
# FP Runner : 0.0
# FK (FlightKid) : 0.0
# FJ Final Join , Circles Game : 0.0
# FG SPINNER : 0.0
# Ez Mirror Match : 0.0
# Extreme X Ray Robot Stunts : 0.0
# Extreme Super Car Driving 3D : 0.0
# Extreme Match : 0.0
# Ew, the small alien : 0.0
# Endless Ducker : 0.0
# EmuBox - Fast Retro Emulator : 0.0
# Elite Commando Shooting War : 0.0
# Eh Amego! : 0.0
# EP Gem Hunter : 0.0
# EF Jumper : 0.0
# EC Mover : 0.0
# E.G. Chess Free : 0.0
# Dubai Racing : 0.0
# Driving Cars Simulator Citroen : 0.0
# Drive 4x4 Luxury SUV Jeep : 0.0
# Drink-O-Tron The Drinking Game : 0.0
# Dreamland Arcade - Steven Universe : 0.0
# Draw A Stickman : 0.0
# Dragon X Adventure: Warrior Z : 0.0
# Dr.Slender Ep 1 Guide (Eng) : 0.0
# Dr. Shogi : 0.0
# Dr. Parker : Real car parking simulation : 0.0
# Dr. Parker : Parking Simulator : 0.0
# Dr. Dominoes : 0.0
# Dr Driving Racer : 0.0
# Dr Dre - Beatmaker : 0.0
# Don't Hug Me I'm So Scared : 0.0
# Dinosaur Simulator: Dino World : 0.0
# Dino War: Rise of Beasts : 0.0
# Dino Defends king 3 – Dinosaur T rex Hunter Games : 0.0
# Destroy Gunners Σ : 0.0
# Destiny Ninja Shall we date otome games love story : 0.0
# Decay: The Mare - Ep.1 (Trial) : 0.0
# Dead Zombie Evil Killer:Axe : 0.0
# Dead Target Zombie Shooting US Sniper Killer Squad : 0.0
# Dash Quest Heroes : 0.0
# DZ-JOKER : 0.0
# DS Tower Defence : 0.0
# DM EVOLUTION : 0.0
# DM Adventure : 0.0
# DK Quiz : 0.0
# DJMAX TECHNIKA Q - Music Game : 0.0
# DH Pineapple Poker OFC : 0.0
# DG Mobile : 0.0
# DF Squid : 0.0
# DC Universe Quiz : 0.0
# DB Ultra Saiyan Battle : 0.0
# D Day World War II Commando Survival Shooting : 0.0
# Cyborg AX-001 : 0.0
# Critical Strike CS: Counter Terrorist Online FPS : 0.0
# Crime Wars S. Andreas : 0.0
# Crazy Bike attack Racing New: motorcycle racing : 0.0
# Crayola Color Blaster : 0.0
# Countries of the European Union (Quiz) : 0.0
# Counter Terrorist Gun Strike CS: Special Forces : 0.0
# Combat Strike CS 🔫 Counter Terrorist Attack FPS💣 : 0.0
# Combat BF: Black Ops 3 : 0.0
# Clash of Axe: Flippy Lumberjack Action X : 0.0
# Chinese Chess / Co Tuong : 0.0
# Chinese Chess ( Xiangqi Free ) : 0.0
# China Town Auto Theft 2 : 0.0
# Carros Rebaixados BR : 0.0
# Cards Casino:Video Poker & BJ : 0.0
# Cardi B Piano Game : 0.0
# Car Driving Simulator Drift : 0.0
# Car Crash III Beam DH Real Damage Simulator 2018 : 0.0
# Camping RV Caravan Parking 3D : 0.0
# CT-ART 4.0 (Chess Tactics 1200-2400 ELO) : 0.0
# CS16Client : 0.0
# CQ: Lost In Transmission : 0.0
# CP Trivia : 0.0
# CNY Slots : Gong Xi Fa Cai 发财机 : 0.0
# CJ: Strike Back : 0.0
# CJ Poker Odds Calculator : 0.0
# C3-C4-PİCASSO-ELYSEE RACİNG : 0.0
# Bullshite! : 0.0
# Bullshit! (Free) : 0.0
# Bubble Shooter Space : 0.0
# Bubble Shooter Genies : 0.0
# Bubble Shooter 2 : 0.0
# Bu Nedir ? : 0.0
# Bu Hangi Ünlü? : 0.0
# Bu Hangi Youtuber ? : 0.0
# Bu Hangi Oyun ? : 0.0
# Bu Hangi Dizi ? : 0.0
# Brick Breaker BR : 0.0
# BombSquad Remote : 0.0
# Blood Domination - BL Game : 0.0
# Block Puzzle Classic Legend ! : 0.0
# Block Gun 3D: Haunted Hollow : 0.0
# Block Battles: Heroes at War - Multiplayer PVP : 0.0
# Blackjack aj Poker : 0.0
# BlackJack 21 Pro : 0.0
# BlackJack -21 Casino Card Game : 0.0
# Black Commando | Special Ops | FPS Shooting : 0.0
# Bi-Tank : 0.0
# Betul Ke Bohong Eh? : 0.0
# Beach Shoot Em Up: Head Hunter : 0.0
# Beach Head Shooting Assault : 0.0
# Basic Strategy Training BJ 21 : 0.0
# Baby Game Animal Jam Free : 0.0
# Ba Cristi : 0.0
# BZ Zombie VR : 0.0
# BZ Fingers : 0.0
# BW-Joseki : 0.0
# BW-Go Free : 0.0
# BW-GnuGo : 0.0
# BW-DGS plugin : 0.0
# BW Switch : 0.0
# BU HANGİ ŞARKI ? - 2018 : 0.0
# BS Tractor : 0.0
# BS Chopper : 0.0
# BROTHER IN WARS: GUNNER CITY WARLORDS : 0.0
# BMX Boy Bike Stunt Rider Game : 0.0
# BL-ED: From BLUE to RED : 0.0
# BL!TZ - Endless : 0.0
# BJ's Bingo & Gaming Casino : 0.0
# BJ card game blackjack : 0.0
# BJ Strategy Tester : 0.0
# BJ Bridge Standard American 2018 : 0.0
# BJ Bridge Free (2018) : 0.0
# BJ Bridge Acol Beginner 2018 : 0.0
# BF at Sea Refueled : 0.0
# BF Combat: Genesis : 0.0
# BEBONCOOL GAMEPAD V1.0 : 0.0
# BC Slots - The Lost Reels FREE : 0.0
# B@dL!bs Lite : 0.0
# Ay Vamos - PJ. Balvin - Piano : 0.0
# Axetatic - Axe Throwing Game : 0.0
# Axe Throw: Flip Champ Axes Champion Throwing Games : 0.0
# Axe Man : 0.0
# Axe Knight : 0.0
# Axe Champs! Wars : 0.0
# Axe Champion : 0.0
# Axe Champ Hit : 0.0
# Axe Champ : 0.0
# Auction Wars : Storage King : 0.0
# Au-allstar for KR : 0.0
# Armored Warfare: Assault : 0.0
# Armed Cam Gun Pack : 0.0
# Arcraft - AR Sandbox : 0.0
# Archery Physics Objects Destruction Apple shooter : 0.0
# Ao Oni2 : 0.0
# Animal Hunting: Sniper Shooting : 0.0
# American Sniper City Fight Shooting Assassin : 0.0
# Alex & Co Quiz : 0.0
# Ah! Coins : 0.0
# Adventure Time Run : 0.0
# Adivina el cantante de Trap y Reggaeton : 0.0
# Adivina el Emoji : 0.0
# AZ Rockets : 0.0
# AXE.IO - Brutal Survival Battleground : 0.0
# AU Mobile Indonesia : 0.0
# AR Tank Battle : 0.0
# AK-47 Assult Rifle: Gun Shooting Simulator Game : 0.0
# AK-47 3D : 0.0
# AK Blackjack : 0.0
# AH-1 Viper Cobra Ops - helicopter flight simulator : 0.0
# AG Drive 3D : 0.0
# AE Video Poker : 0.0
# AE Spider Solitaire : 0.0
# AE Solitaire : 0.0
# AE Master Moto : 0.0
# AE Lucky Fishing : 0.0
# AE Jewels 2: Island Adventures : 0.0
# AE Jewels : 0.0
# AE Gun Ball: arcade ball games : 0.0
# AE GTO Racing : 0.0
# AE FreeCell : 0.0
# AE Fishing Hunter : 0.0
# AE City Jump : 0.0
# AE Blackjack : 0.0
# AE Angry Chef : 0.0
# AE 3D Moto 3 : 0.0
# 7 Nights at Pixel Pizzeria - 2 : 0.0
# 5 Nights at Cube Pizzeria City : 0.0
# 4x4 Jeep Racer : 0.0
# 4 in a Row : 0.0
# 211:CK Lite : 0.0
# 2-Player Co-op Zombie Shoot : 0.0

# %% [markdown]
# For both datasets, the games genre is pretty evenly spread. I would suggest a deeper dive investigation into the top games. Find one that has game mechanics that could be duplicated but given a new and fresh theme. Make sure to use some very catchy ads to draw users to your game and offer codes to provide free goodies.

# %% [markdown]
# ## Conclusion
#
# In this project, we took mobile store datasets and cleaned them up and filtered them down until they only contained apps similar to what we wanted to develop. For this situation, that meant only free apps in English.
#
# After that, we wanted to find out which apps were the most popular since our new app will gain revenue through ads. This means more users using our free app will generate more ad displays.
#
# We decided to first use the genre of the apps to narrow our scope. We found the most popular genres by average number of user ratings, but when we investigated the top apps of those genres, we found a few apps dominated the top. This caused skewing in our averages since we know our brand new app is not going to instantly compete with those giants.
#
# After removing the top skewing apps, our averages looked quite different in Android vs iOS. Even though the "Games" genre was only middle of the pack on iOS, the averages were fairly evenly distributed, meaning it should be easier for our new app to get a peice of the pie.
#
# The final suggestion to the app developers is to create a game similar to one of the top games (both datasets have similar lists). With a core game decided on, give it a fresh theme and some new features to lure new users. The people playing the top games for a long time may tire and want something new, so if you present them with something they are familiar with, they can jump right over to your new app.
